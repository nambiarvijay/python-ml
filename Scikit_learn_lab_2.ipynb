# %% [markdown]
# <a href="https://colab.research.google.com/github/nambiarvijay/python-ml/blob/master/Scikit_learn_lab_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# This example has been taken from SciKit documentation and has been
# modifified to suit this assignment. You are free to make changes, but you
# need to perform the task asked in the lab assignment


from __future__ import print_function

from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC

print(__doc__)

# Loading the wine dataset
wine = datasets.load_wine()
# Out:
# Automatically created module for IPython interactive environment

# %%
# To apply an classifier on this data, we need to flatten the image, to
# turn the data in a (samples, feature) matrix:
# n_samples = len(digits.images)

X = wine.data
print(wine.target_names)
y = wine.target
# Out:
# ['class_0' 'class_1' 'class_2']

# %%
# Split the dataset in two equal parts into 80:20 ratio for train:test
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=13)


# We are going to limit ourselves to accuracy score, other options can be
# seen here:
# http://scikit-learn.org/stable/modules/model_evaluation.html#scoring-parameter
# Some other values used are the predcision_macro, recall_macro
scores = ['accuracy']

# %%
# For support vector machine 
# This is a key step where you define the parameters and their possible values
# that you would like to check.
tuned_parameters = [{'kernel': ['poly'],'degree':[3,4,5],
#                      'max_iter':[5000],
                     'random_state':[54,76],
                     'C': [1,10,100,1000]}
                    ]

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(SVC(), tuned_parameters, cv=5,
                       scoring='%s' % score)
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred))
    print("Detailed confusion matrix:")
    print(confusion_matrix(y_true, y_pred))
    print("Accuracy Score: \n")
    print(accuracy_score(y_true, y_pred))

    print()

# Note the problem is too easy: the hyperparameter plateau is too flat and the
# output model is the same for precision and recall with ties in quality.
# Out:
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set:
#
# {'C': 1, 'degree': 3, 'kernel': 'poly', 'random_state': 54}
#
# Grid scores on development set:
#
# 0.937 (+/-0.144) for {'C': 1, 'degree': 3, 'kernel': 'poly', 'random_state': 54}
# 0.937 (+/-0.144) for {'C': 1, 'degree': 3, 'kernel': 'poly', 'random_state': 76}
# 0.923 (+/-0.167) for {'C': 1, 'degree': 4, 'kernel': 'poly', 'random_state': 54}
# 0.923 (+/-0.167) for {'C': 1, 'degree': 4, 'kernel': 'poly', 'random_state': 76}
# 0.930 (+/-0.176) for {'C': 1, 'degree': 5, 'kernel': 'poly', 'random_state': 54}
# 0.930 (+/-0.176) for {'C': 1, 'degree': 5, 'kernel': 'poly', 'random_state': 76}
# 0.937 (+/-0.144) for {'C': 10, 'degree': 3, 'kernel': 'poly', 'random_state': 54}
# 0.937 (+/-0.144) for {'C': 10, 'degree': 3, 'kernel': 'poly', 'random_state': 76}
# 0.923 (+/-0.167) for {'C': 10, 'degree': 4, 'kernel': 'poly', 'random_state': 54}
# 0.923 (+/-0.167) for {'C': 10, 'degree': 4, 'kernel': 'poly', 'random_state': 76}
# 0.930 (+/-0.176) for {'C': 10, 'degree': 5, 'kernel': 'poly', 'random_state': 54}
# 0.930 (+/-0.176) for {'C': 10, 'degree': 5, 'kernel': 'poly', 'random_state': 76}
# 0.937 (+/-0.144) for {'C': 100, 'degree': 3, 'kernel': 'poly', 'random_state': 54}
# 0.937 (+/-0.144) for {'C': 100, 'degree': 3, 'kernel': 'poly', 'random_state': 76}
# 0.923 (+/-0.167) for {'C': 100, 'degree': 4, 'kernel': 'poly', 'random_state': 54}
# 0.923 (+/-0.167) for {'C': 100, 'degree': 4, 'kernel': 'poly', 'random_state': 76}
# 0.930 (+/-0.176) for {'C': 100, 'degree': 5, 'kernel': 'poly', 'random_state': 54}
# 0.930 (+/-0.176) for {'C': 100, 'degree': 5, 'kernel': 'poly', 'random_state': 76}
# 0.937 (+/-0.144) for {'C': 1000, 'degree': 3, 'kernel': 'poly', 'random_state': 54}
# 0.937 (+/-0.144) for {'C': 1000, 'degree': 3, 'kernel': 'poly', 'random_state': 76}
# 0.923 (+/-0.167) for {'C': 1000, 'degree': 4, 'kernel': 'poly', 'random_state': 54}
# 0.923 (+/-0.167) for {'C': 1000, 'degree': 4, 'kernel': 'poly', 'random_state': 76}
# 0.930 (+/-0.176) for {'C': 1000, 'degree': 5, 'kernel': 'poly', 'random_state': 54}
# 0.930 (+/-0.176) for {'C': 1000, 'degree': 5, 'kernel': 'poly', 'random_state': 76}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00        12
#           1       0.94      1.00      0.97        15
#           2       1.00      0.89      0.94         9
#
# avg / total       0.97      0.97      0.97        36
#
# Detailed confusion matrix:
# [[12  0  0]
#  [ 0 15  0]
#  [ 0  1  8]]
# Accuracy Score:
#
# 0.9722222222222222

# %%
# For Decision Tree Classifier
from sklearn.tree import DecisionTreeClassifier
# This is a key step where you define the parameters and their possible values
# that you would like to check.
tuned_parameters = [{'max_depth':[10,20,30,40],
'min_samples_split':[2,3,4],
#The minimum number of samples required to be at a leaf node
'min_samples_leaf':[1,3,5,7],
'max_features':[5,7,8,10,12],
'max_leaf_nodes':[20,30,40,50]}
                    ]

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(DecisionTreeClassifier(), tuned_parameters, cv=5,
                       scoring='%s' % score)
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred))
    print("Detailed confusion matrix:")
    print(confusion_matrix(y_true, y_pred))
    print("Accuracy Score: \n")
    print(accuracy_score(y_true, y_pred))

    print()
# Out:
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set:
#
# {'max_depth': 30, 'max_features': 8, 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 4}
#
# Grid scores on development set:
#
# 0.901 (+/-0.098) for {'max_depth': 10, 'max_features': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.880 (+/-0.100) for {'max_depth': 10, 'max_features': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 3}
# 0.915 (+/-0.117) for {'max_depth': 10, 'max_features': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 4}
# 0.866 (+/-0.104) for {'max_depth': 10, 'max_features': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.901 (+/-0.024) for {'max_depth': 10, 'max_features': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 3, 'min_samples_split': 3}
# 0.873 (+/-0.136) for {'max_depth': 10, 'max_features': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 3, 'min_samples_split': 4}
# 0.852 (+/-0.101) for {'max_depth': 10, 'max_features': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.859 (+/-0.110) for {'max_depth': 10, 'max_features': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 3}
# 0.873 (+/-0.052) for {'max_depth': 10, 'max_features': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 4}
# 0.845 (+/-0.097) for {'max_depth': 10, 'max_features': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 7, 'min_samples_split': 2}
# 0.824 (+/-0.118) for {'max_depth': 10, 'max_features': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 7, 'min_samples_split': 3}
# 0.880 (+/-0.064) for {'max_depth': 10, 'max_features': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 7, 'min_samples_split': 4}
# 0.887 (+/-0.209) for {'max_depth': 10, 'max_features': 5, 'max_leaf_nodes': 30, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.894 (+/-0.112) for {'max_depth': 10, 'max_features': 5, 'max_leaf_nodes': 30, 'min_samples_leaf': 1, 'min_samples_split': 3}
# 0.887 (+/-0.100) for {'max_depth': 10, 'max_features': 5, 'max_leaf_nodes': 30, 'min_samples_leaf': 1, 'min_samples_split': 4}
# 0.852 (+/-0.126) for {'max_depth': 10, 'max_features': 5, 'max_leaf_nodes': 30, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.887 (+/-0.116) for {'max_depth': 10, 'max_features': 5, 'max_leaf_nodes': 30, 'min_samples_leaf': 3, 'min_samples_split': 3}
# 0.908 (+/-0.091) for {'max_depth': 10, 'max_features': 5, 'max_leaf_nodes': 30, 'min_samples_leaf': 3, 'min_samples_split': 4}
# 0.887 (+/-0.101) for {'max_depth': 10, 'max_features': 5, 'max_leaf_nodes': 30, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.859 (+/-0.087) for {'max_depth': 10, 'max_features': 5, 'max_leaf_nodes': 30, 'min_samples_leaf': 5, 'min_samples_split': 3}
# 0.866 (+/-0.083) for {'max_depth': 10, 'max_features': 5, 'max_leaf_nodes': 30, 'min_samples_leaf': 5, 'min_samples_split': 4}
# 0.866 (+/-0.138) for {'max_depth': 10, 'max_features': 5, 'max_leaf_nodes': 30, 'min_samples_leaf': 7, 'min_samples_split': 2}
# 0.852 (+/-0.116) for {'max_depth': 10, 'max_features': 5, 'max_leaf_nodes': 30, 'min_samples_leaf': 7, 'min_samples_split': 3}
# 0.824 (+/-0.123) for {'max_depth': 10, 'max_features': 5, 'max_leaf_nodes': 30, 'min_samples_leaf': 7, 'min_samples_split': 4}
# 0.859 (+/-0.060) for {'max_depth': 10, 'max_features': 5, 'max_leaf_nodes': 40, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.866 (+/-0.112) for {'max_depth': 10, 'max_features': 5, 'max_leaf_nodes': 40, 'min_samples_leaf': 1, 'min_samples_split': 3}
# 0.901 (+/-0.067) for {'max_depth': 10, 'max_features': 5, 'max_leaf_nodes': 40, 'min_samples_leaf': 1, 'min_samples_split': 4}
# 0.880 (+/-0.104) for {'max_depth': 10, 'max_features': 5, 'max_leaf_nodes': 40, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.894 (+/-0.122) for {'max_depth': 10, 'max_features': 5, 'max_leaf_nodes': 40, 'min_samples_leaf': 3, 'min_samples_split': 3}
# 0.845 (+/-0.109) for {'max_depth': 10, 'max_features': 5, 'max_leaf_nodes': 40, 'min_samples_leaf': 3, 'min_samples_split': 4}
# 0.866 (+/-0.125) for {'max_depth': 10, 'max_features': 5, 'max_leaf_nodes': 40, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.915 (+/-0.054) for {'max_depth': 10, 'max_features': 5, 'max_leaf_nodes': 40, 'min_samples_leaf': 5, 'min_samples_split': 3}
# 0.880 (+/-0.082) for {'max_depth': 10, 'max_features': 5, 'max_leaf_nodes': 40, 'min_samples_leaf': 5, 'min_samples_split': 4}
# 0.852 (+/-0.107) for {'max_depth': 10, 'max_features': 5, 'max_leaf_nodes': 40, 'min_samples_leaf': 7, 'min_samples_split': 2}
# 0.866 (+/-0.138) for {'max_depth': 10, 'max_features': 5, 'max_leaf_nodes': 40, 'min_samples_leaf': 7, 'min_samples_split': 3}
# 0.824 (+/-0.143) for {'max_depth': 10, 'max_features': 5, 'max_leaf_nodes': 40, 'min_samples_leaf': 7, 'min_samples_split': 4}
# 0.831 (+/-0.069) for {'max_depth': 10, 'max_features': 5, 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.915 (+/-0.070) for {'max_depth': 10, 'max_features': 5, 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 3}
# 0.908 (+/-0.102) for {'max_depth': 10, 'max_features': 5, 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 4}
# 0.873 (+/-0.113) for {'max_depth': 10, 'max_features': 5, 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.859 (+/-0.099) for {'max_depth': 10, 'max_features': 5, 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 3}
# 0.838 (+/-0.103) for {'max_depth': 10, 'max_features': 5, 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 4}
# 0.894 (+/-0.125) for {'max_depth': 10, 'max_features': 5, 'max_leaf_nodes': 50, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.831 (+/-0.046) for {'max_depth': 10, 'max_features': 5, 'max_leaf_nodes': 50, 'min_samples_leaf': 5, 'min_samples_split': 3}
# 0.859 (+/-0.178) for {'max_depth': 10, 'max_features': 5, 'max_leaf_nodes': 50, 'min_samples_leaf': 5, 'min_samples_split': 4}
# 0.866 (+/-0.072) for {'max_depth': 10, 'max_features': 5, 'max_leaf_nodes': 50, 'min_samples_leaf': 7, 'min_samples_split': 2}
# 0.852 (+/-0.096) for {'max_depth': 10, 'max_features': 5, 'max_leaf_nodes': 50, 'min_samples_leaf': 7, 'min_samples_split': 3}
# 0.887 (+/-0.076) for {'max_depth': 10, 'max_features': 5, 'max_leaf_nodes': 50, 'min_samples_leaf': 7, 'min_samples_split': 4}
# 0.901 (+/-0.105) for {'max_depth': 10, 'max_features': 7, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.915 (+/-0.075) for {'max_depth': 10, 'max_features': 7, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 3}
# 0.901 (+/-0.051) for {'max_depth': 10, 'max_features': 7, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 4}
# 0.908 (+/-0.073) for {'max_depth': 10, 'max_features': 7, 'max_leaf_nodes': 20, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.894 (+/-0.090) for {'max_depth': 10, 'max_features': 7, 'max_leaf_nodes': 20, 'min_samples_leaf': 3, 'min_samples_split': 3}
# 0.901 (+/-0.122) for {'max_depth': 10, 'max_features': 7, 'max_leaf_nodes': 20, 'min_samples_leaf': 3, 'min_samples_split': 4}
# 0.845 (+/-0.130) for {'max_depth': 10, 'max_features': 7, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.831 (+/-0.095) for {'max_depth': 10, 'max_features': 7, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 3}
# 0.880 (+/-0.093) for {'max_depth': 10, 'max_features': 7, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 4}
# 0.845 (+/-0.099) for {'max_depth': 10, 'max_features': 7, 'max_leaf_nodes': 20, 'min_samples_leaf': 7, 'min_samples_split': 2}
# 0.838 (+/-0.142) for {'max_depth': 10, 'max_features': 7, 'max_leaf_nodes': 20, 'min_samples_leaf': 7, 'min_samples_split': 3}
# 0.803 (+/-0.102) for {'max_depth': 10, 'max_features': 7, 'max_leaf_nodes': 20, 'min_samples_leaf': 7, 'min_samples_split': 4}
# 0.908 (+/-0.069) for {'max_depth': 10, 'max_features': 7, 'max_leaf_nodes': 30, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.908 (+/-0.066) for {'max_depth': 10, 'max_features': 7, 'max_leaf_nodes': 30, 'min_samples_leaf': 1, 'min_samples_split': 3}
# 0.915 (+/-0.143) for {'max_depth': 10, 'max_features': 7, 'max_leaf_nodes': 30, 'min_samples_leaf': 1, 'min_samples_split': 4}
# 0.887 (+/-0.123) for {'max_depth': 10, 'max_features': 7, 'max_leaf_nodes': 30, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.859 (+/-0.104) for {'max_depth': 10, 'max_features': 7, 'max_leaf_nodes': 30, 'min_samples_leaf': 3, 'min_samples_split': 3}
# 0.880 (+/-0.091) for {'max_depth': 10, 'max_features': 7, 'max_leaf_nodes': 30, 'min_samples_leaf': 3, 'min_samples_split': 4}
# 0.873 (+/-0.135) for {'max_depth': 10, 'max_features': 7, 'max_leaf_nodes': 30, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.838 (+/-0.111) for {'max_depth': 10, 'max_features': 7, 'max_leaf_nodes': 30, 'min_samples_leaf': 5, 'min_samples_split': 3}
# 0.873 (+/-0.109) for {'max_depth': 10, 'max_features': 7, 'max_leaf_nodes': 30, 'min_samples_leaf': 5, 'min_samples_split': 4}
# 0.838 (+/-0.127) for {'max_depth': 10, 'max_features': 7, 'max_leaf_nodes': 30, 'min_samples_leaf': 7, 'min_samples_split': 2}
# 0.866 (+/-0.081) for {'max_depth': 10, 'max_features': 7, 'max_leaf_nodes': 30, 'min_samples_leaf': 7, 'min_samples_split': 3}
# 0.866 (+/-0.169) for {'max_depth': 10, 'max_features': 7, 'max_leaf_nodes': 30, 'min_samples_leaf': 7, 'min_samples_split': 4}
# 0.915 (+/-0.057) for {'max_depth': 10, 'max_features': 7, 'max_leaf_nodes': 40, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.880 (+/-0.152) for {'max_depth': 10, 'max_features': 7, 'max_leaf_nodes': 40, 'min_samples_leaf': 1, 'min_samples_split': 3}
# 0.923 (+/-0.082) for {'max_depth': 10, 'max_features': 7, 'max_leaf_nodes': 40, 'min_samples_leaf': 1, 'min_samples_split': 4}
# 0.887 (+/-0.116) for {'max_depth': 10, 'max_features': 7, 'max_leaf_nodes': 40, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.859 (+/-0.122) for {'max_depth': 10, 'max_features': 7, 'max_leaf_nodes': 40, 'min_samples_leaf': 3, 'min_samples_split': 3}
# 0.901 (+/-0.156) for {'max_depth': 10, 'max_features': 7, 'max_leaf_nodes': 40, 'min_samples_leaf': 3, 'min_samples_split': 4}
# 0.866 (+/-0.104) for {'max_depth': 10, 'max_features': 7, 'max_leaf_nodes': 40, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.859 (+/-0.137) for {'max_depth': 10, 'max_features': 7, 'max_leaf_nodes': 40, 'min_samples_leaf': 5, 'min_samples_split': 3}
# 0.880 (+/-0.112) for {'max_depth': 10, 'max_features': 7, 'max_leaf_nodes': 40, 'min_samples_leaf': 5, 'min_samples_split': 4}
# 0.831 (+/-0.114) for {'max_depth': 10, 'max_features': 7, 'max_leaf_nodes': 40, 'min_samples_leaf': 7, 'min_samples_split': 2}
# 0.866 (+/-0.128) for {'max_depth': 10, 'max_features': 7, 'max_leaf_nodes': 40, 'min_samples_leaf': 7, 'min_samples_split': 3}
# 0.852 (+/-0.088) for {'max_depth': 10, 'max_features': 7, 'max_leaf_nodes': 40, 'min_samples_leaf': 7, 'min_samples_split': 4}
# 0.873 (+/-0.060) for {'max_depth': 10, 'max_features': 7, 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.923 (+/-0.148) for {'max_depth': 10, 'max_features': 7, 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 3}
# 0.880 (+/-0.120) for {'max_depth': 10, 'max_features': 7, 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 4}
# 0.873 (+/-0.047) for {'max_depth': 10, 'max_features': 7, 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.859 (+/-0.091) for {'max_depth': 10, 'max_features': 7, 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 3}
# 0.866 (+/-0.089) for {'max_depth': 10, 'max_features': 7, 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 4}
# 0.894 (+/-0.059) for {'max_depth': 10, 'max_features': 7, 'max_leaf_nodes': 50, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.852 (+/-0.134) for {'max_depth': 10, 'max_features': 7, 'max_leaf_nodes': 50, 'min_samples_leaf': 5, 'min_samples_split': 3}
# 0.866 (+/-0.082) for {'max_depth': 10, 'max_features': 7, 'max_leaf_nodes': 50, 'min_samples_leaf': 5, 'min_samples_split': 4}
# 0.859 (+/-0.135) for {'max_depth': 10, 'max_features': 7, 'max_leaf_nodes': 50, 'min_samples_leaf': 7, 'min_samples_split': 2}
# 0.887 (+/-0.101) for {'max_depth': 10, 'max_features': 7, 'max_leaf_nodes': 50, 'min_samples_leaf': 7, 'min_samples_split': 3}
# 0.873 (+/-0.116) for {'max_depth': 10, 'max_features': 7, 'max_leaf_nodes': 50, 'min_samples_leaf': 7, 'min_samples_split': 4}
# 0.880 (+/-0.070) for {'max_depth': 10, 'max_features': 8, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.908 (+/-0.112) for {'max_depth': 10, 'max_features': 8, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 3}
# 0.887 (+/-0.124) for {'max_depth': 10, 'max_features': 8, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 4}
# 0.887 (+/-0.050) for {'max_depth': 10, 'max_features': 8, 'max_leaf_nodes': 20, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.866 (+/-0.138) for {'max_depth': 10, 'max_features': 8, 'max_leaf_nodes': 20, 'min_samples_leaf': 3, 'min_samples_split': 3}
# 0.859 (+/-0.087) for {'max_depth': 10, 'max_features': 8, 'max_leaf_nodes': 20, 'min_samples_leaf': 3, 'min_samples_split': 4}
# 0.824 (+/-0.091) for {'max_depth': 10, 'max_features': 8, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.866 (+/-0.129) for {'max_depth': 10, 'max_features': 8, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 3}
# 0.859 (+/-0.119) for {'max_depth': 10, 'max_features': 8, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 4}
# 0.866 (+/-0.050) for {'max_depth': 10, 'max_features': 8, 'max_leaf_nodes': 20, 'min_samples_leaf': 7, 'min_samples_split': 2}
# 0.824 (+/-0.104) for {'max_depth': 10, 'max_features': 8, 'max_leaf_nodes': 20, 'min_samples_leaf': 7, 'min_samples_split': 3}
# 0.873 (+/-0.050) for {'max_depth': 10, 'max_features': 8, 'max_leaf_nodes': 20, 'min_samples_leaf': 7, 'min_samples_split': 4}
# 0.930 (+/-0.078) for {'max_depth': 10, 'max_features': 8, 'max_leaf_nodes': 30, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.894 (+/-0.043) for {'max_depth': 10, 'max_features': 8, 'max_leaf_nodes': 30, 'min_samples_leaf': 1, 'min_samples_split': 3}
# 0.923 (+/-0.089) for {'max_depth': 10, 'max_features': 8, 'max_leaf_nodes': 30, 'min_samples_leaf': 1, 'min_samples_split': 4}
# 0.901 (+/-0.049) for {'max_depth': 10, 'max_features': 8, 'max_leaf_nodes': 30, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.901 (+/-0.087) for {'max_depth': 10, 'max_features': 8, 'max_leaf_nodes': 30, 'min_samples_leaf': 3, 'min_samples_split': 3}
# 0.908 (+/-0.098) for {'max_depth': 10, 'max_features': 8, 'max_leaf_nodes': 30, 'min_samples_leaf': 3, 'min_samples_split': 4}
# 0.866 (+/-0.092) for {'max_depth': 10, 'max_features': 8, 'max_leaf_nodes': 30, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.894 (+/-0.080) for {'max_depth': 10, 'max_features': 8, 'max_leaf_nodes': 30, 'min_samples_leaf': 5, 'min_samples_split': 3}
# 0.831 (+/-0.145) for {'max_depth': 10, 'max_features': 8, 'max_leaf_nodes': 30, 'min_samples_leaf': 5, 'min_samples_split': 4}
# 0.866 (+/-0.110) for {'max_depth': 10, 'max_features': 8, 'max_leaf_nodes': 30, 'min_samples_leaf': 7, 'min_samples_split': 2}
# 0.845 (+/-0.104) for {'max_depth': 10, 'max_features': 8, 'max_leaf_nodes': 30, 'min_samples_leaf': 7, 'min_samples_split': 3}
# 0.838 (+/-0.114) for {'max_depth': 10, 'max_features': 8, 'max_leaf_nodes': 30, 'min_samples_leaf': 7, 'min_samples_split': 4}
# 0.908 (+/-0.149) for {'max_depth': 10, 'max_features': 8, 'max_leaf_nodes': 40, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.894 (+/-0.147) for {'max_depth': 10, 'max_features': 8, 'max_leaf_nodes': 40, 'min_samples_leaf': 1, 'min_samples_split': 3}
# 0.866 (+/-0.118) for {'max_depth': 10, 'max_features': 8, 'max_leaf_nodes': 40, 'min_samples_leaf': 1, 'min_samples_split': 4}
# 0.887 (+/-0.165) for {'max_depth': 10, 'max_features': 8, 'max_leaf_nodes': 40, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.873 (+/-0.068) for {'max_depth': 10, 'max_features': 8, 'max_leaf_nodes': 40, 'min_samples_leaf': 3, 'min_samples_split': 3}
# 0.852 (+/-0.083) for {'max_depth': 10, 'max_features': 8, 'max_leaf_nodes': 40, 'min_samples_leaf': 3, 'min_samples_split': 4}
# 0.880 (+/-0.118) for {'max_depth': 10, 'max_features': 8, 'max_leaf_nodes': 40, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.845 (+/-0.093) for {'max_depth': 10, 'max_features': 8, 'max_leaf_nodes': 40, 'min_samples_leaf': 5, 'min_samples_split': 3}
# 0.866 (+/-0.120) for {'max_depth': 10, 'max_features': 8, 'max_leaf_nodes': 40, 'min_samples_leaf': 5, 'min_samples_split': 4}
# 0.845 (+/-0.125) for {'max_depth': 10, 'max_features': 8, 'max_leaf_nodes': 40, 'min_samples_leaf': 7, 'min_samples_split': 2}
# 0.845 (+/-0.132) for {'max_depth': 10, 'max_features': 8, 'max_leaf_nodes': 40, 'min_samples_leaf': 7, 'min_samples_split': 3}
# 0.831 (+/-0.099) for {'max_depth': 10, 'max_features': 8, 'max_leaf_nodes': 40, 'min_samples_leaf': 7, 'min_samples_split': 4}
# 0.887 (+/-0.069) for {'max_depth': 10, 'max_features': 8, 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.880 (+/-0.123) for {'max_depth': 10, 'max_features': 8, 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 3}
# 0.880 (+/-0.135) for {'max_depth': 10, 'max_features': 8, 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 4}
# 0.873 (+/-0.122) for {'max_depth': 10, 'max_features': 8, 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.859 (+/-0.100) for {'max_depth': 10, 'max_features': 8, 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 3}
# 0.894 (+/-0.111) for {'max_depth': 10, 'max_features': 8, 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 4}
# 0.873 (+/-0.142) for {'max_depth': 10, 'max_features': 8, 'max_leaf_nodes': 50, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.845 (+/-0.172) for {'max_depth': 10, 'max_features': 8, 'max_leaf_nodes': 50, 'min_samples_leaf': 5, 'min_samples_split': 3}
# 0.887 (+/-0.135) for {'max_depth': 10, 'max_features': 8, 'max_leaf_nodes': 50, 'min_samples_leaf': 5, 'min_samples_split': 4}
# 0.838 (+/-0.095) for {'max_depth': 10, 'max_features': 8, 'max_leaf_nodes': 50, 'min_samples_leaf': 7, 'min_samples_split': 2}
# 0.866 (+/-0.182) for {'max_depth': 10, 'max_features': 8, 'max_leaf_nodes': 50, 'min_samples_leaf': 7, 'min_samples_split': 3}
# 0.810 (+/-0.139) for {'max_depth': 10, 'max_features': 8, 'max_leaf_nodes': 50, 'min_samples_leaf': 7, 'min_samples_split': 4}
# 0.866 (+/-0.100) for {'max_depth': 10, 'max_features': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.915 (+/-0.104) for {'max_depth': 10, 'max_features': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 3}
# 0.908 (+/-0.068) for {'max_depth': 10, 'max_features': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 4}
# 0.915 (+/-0.098) for {'max_depth': 10, 'max_features': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.887 (+/-0.031) for {'max_depth': 10, 'max_features': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 3, 'min_samples_split': 3}
# 0.880 (+/-0.070) for {'max_depth': 10, 'max_features': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 3, 'min_samples_split': 4}
# 0.887 (+/-0.078) for {'max_depth': 10, 'max_features': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.873 (+/-0.146) for {'max_depth': 10, 'max_features': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 3}
# 0.845 (+/-0.137) for {'max_depth': 10, 'max_features': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 4}
# 0.824 (+/-0.189) for {'max_depth': 10, 'max_features': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 7, 'min_samples_split': 2}
# 0.838 (+/-0.198) for {'max_depth': 10, 'max_features': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 7, 'min_samples_split': 3}
# 0.831 (+/-0.140) for {'max_depth': 10, 'max_features': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 7, 'min_samples_split': 4}
# 0.915 (+/-0.058) for {'max_depth': 10, 'max_features': 10, 'max_leaf_nodes': 30, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.908 (+/-0.030) for {'max_depth': 10, 'max_features': 10, 'max_leaf_nodes': 30, 'min_samples_leaf': 1, 'min_samples_split': 3}
# 0.901 (+/-0.102) for {'max_depth': 10, 'max_features': 10, 'max_leaf_nodes': 30, 'min_samples_leaf': 1, 'min_samples_split': 4}
# 0.852 (+/-0.046) for {'max_depth': 10, 'max_features': 10, 'max_leaf_nodes': 30, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.894 (+/-0.112) for {'max_depth': 10, 'max_features': 10, 'max_leaf_nodes': 30, 'min_samples_leaf': 3, 'min_samples_split': 3}
# 0.852 (+/-0.104) for {'max_depth': 10, 'max_features': 10, 'max_leaf_nodes': 30, 'min_samples_leaf': 3, 'min_samples_split': 4}
# 0.845 (+/-0.143) for {'max_depth': 10, 'max_features': 10, 'max_leaf_nodes': 30, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.852 (+/-0.136) for {'max_depth': 10, 'max_features': 10, 'max_leaf_nodes': 30, 'min_samples_leaf': 5, 'min_samples_split': 3}
# 0.880 (+/-0.102) for {'max_depth': 10, 'max_features': 10, 'max_leaf_nodes': 30, 'min_samples_leaf': 5, 'min_samples_split': 4}
# 0.831 (+/-0.157) for {'max_depth': 10, 'max_features': 10, 'max_leaf_nodes': 30, 'min_samples_leaf': 7, 'min_samples_split': 2}
# 0.831 (+/-0.140) for {'max_depth': 10, 'max_features': 10, 'max_leaf_nodes': 30, 'min_samples_leaf': 7, 'min_samples_split': 3}
# 0.838 (+/-0.127) for {'max_depth': 10, 'max_features': 10, 'max_leaf_nodes': 30, 'min_samples_leaf': 7, 'min_samples_split': 4}
# 0.901 (+/-0.072) for {'max_depth': 10, 'max_features': 10, 'max_leaf_nodes': 40, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.887 (+/-0.052) for {'max_depth': 10, 'max_features': 10, 'max_leaf_nodes': 40, 'min_samples_leaf': 1, 'min_samples_split': 3}
# 0.937 (+/-0.050) for {'max_depth': 10, 'max_features': 10, 'max_leaf_nodes': 40, 'min_samples_leaf': 1, 'min_samples_split': 4}
# 0.838 (+/-0.141) for {'max_depth': 10, 'max_features': 10, 'max_leaf_nodes': 40, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.901 (+/-0.084) for {'max_depth': 10, 'max_features': 10, 'max_leaf_nodes': 40, 'min_samples_leaf': 3, 'min_samples_split': 3}
# 0.859 (+/-0.117) for {'max_depth': 10, 'max_features': 10, 'max_leaf_nodes': 40, 'min_samples_leaf': 3, 'min_samples_split': 4}
# 0.845 (+/-0.134) for {'max_depth': 10, 'max_features': 10, 'max_leaf_nodes': 40, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.859 (+/-0.113) for {'max_depth': 10, 'max_features': 10, 'max_leaf_nodes': 40, 'min_samples_leaf': 5, 'min_samples_split': 3}
# 0.852 (+/-0.132) for {'max_depth': 10, 'max_features': 10, 'max_leaf_nodes': 40, 'min_samples_leaf': 5, 'min_samples_split': 4}
# 0.824 (+/-0.131) for {'max_depth': 10, 'max_features': 10, 'max_leaf_nodes': 40, 'min_samples_leaf': 7, 'min_samples_split': 2}
# 0.852 (+/-0.136) for {'max_depth': 10, 'max_features': 10, 'max_leaf_nodes': 40, 'min_samples_leaf': 7, 'min_samples_split': 3}
# 0.831 (+/-0.140) for {'max_depth': 10, 'max_features': 10, 'max_leaf_nodes': 40, 'min_samples_leaf': 7, 'min_samples_split': 4}
# 0.894 (+/-0.065) for {'max_depth': 10, 'max_features': 10, 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.880 (+/-0.075) for {'max_depth': 10, 'max_features': 10, 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 3}
# 0.894 (+/-0.131) for {'max_depth': 10, 'max_features': 10, 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 4}
# 0.866 (+/-0.089) for {'max_depth': 10, 'max_features': 10, 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.852 (+/-0.104) for {'max_depth': 10, 'max_features': 10, 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 3}
# 0.852 (+/-0.135) for {'max_depth': 10, 'max_features': 10, 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 4}
# 0.845 (+/-0.090) for {'max_depth': 10, 'max_features': 10, 'max_leaf_nodes': 50, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.894 (+/-0.068) for {'max_depth': 10, 'max_features': 10, 'max_leaf_nodes': 50, 'min_samples_leaf': 5, 'min_samples_split': 3}
# 0.880 (+/-0.143) for {'max_depth': 10, 'max_features': 10, 'max_leaf_nodes': 50, 'min_samples_leaf': 5, 'min_samples_split': 4}
# 0.824 (+/-0.122) for {'max_depth': 10, 'max_features': 10, 'max_leaf_nodes': 50, 'min_samples_leaf': 7, 'min_samples_split': 2}
# 0.866 (+/-0.142) for {'max_depth': 10, 'max_features': 10, 'max_leaf_nodes': 50, 'min_samples_leaf': 7, 'min_samples_split': 3}
# 0.831 (+/-0.095) for {'max_depth': 10, 'max_features': 10, 'max_leaf_nodes': 50, 'min_samples_leaf': 7, 'min_samples_split': 4}
# 0.894 (+/-0.058) for {'max_depth': 10, 'max_features': 12, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.908 (+/-0.095) for {'max_depth': 10, 'max_features': 12, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 3}
# 0.901 (+/-0.122) for {'max_depth': 10, 'max_features': 12, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 4}
# 0.873 (+/-0.122) for {'max_depth': 10, 'max_features': 12, 'max_leaf_nodes': 20, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.866 (+/-0.084) for {'max_depth': 10, 'max_features': 12, 'max_leaf_nodes': 20, 'min_samples_leaf': 3, 'min_samples_split': 3}
# 0.901 (+/-0.062) for {'max_depth': 10, 'max_features': 12, 'max_leaf_nodes': 20, 'min_samples_leaf': 3, 'min_samples_split': 4}
# 0.859 (+/-0.131) for {'max_depth': 10, 'max_features': 12, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.845 (+/-0.104) for {'max_depth': 10, 'max_features': 12, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 3}
# 0.866 (+/-0.089) for {'max_depth': 10, 'max_features': 12, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 4}
# 0.831 (+/-0.154) for {'max_depth': 10, 'max_features': 12, 'max_leaf_nodes': 20, 'min_samples_leaf': 7, 'min_samples_split': 2}
# 0.817 (+/-0.114) for {'max_depth': 10, 'max_features': 12, 'max_leaf_nodes': 20, 'min_samples_leaf': 7, 'min_samples_split': 3}
# 0.810 (+/-0.101) for {'max_depth': 10, 'max_features': 12, 'max_leaf_nodes': 20, 'min_samples_leaf': 7, 'min_samples_split': 4}
# 0.915 (+/-0.121) for {'max_depth': 10, 'max_features': 12, 'max_leaf_nodes': 30, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.880 (+/-0.164) for {'max_depth': 10, 'max_features': 12, 'max_leaf_nodes': 30, 'min_samples_leaf': 1, 'min_samples_split': 3}
# 0.887 (+/-0.079) for {'max_depth': 10, 'max_features': 12, 'max_leaf_nodes': 30, 'min_samples_leaf': 1, 'min_samples_split': 4}
# 0.873 (+/-0.097) for {'max_depth': 10, 'max_features': 12, 'max_leaf_nodes': 30, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.866 (+/-0.128) for {'max_depth': 10, 'max_features': 12, 'max_leaf_nodes': 30, 'min_samples_leaf': 3, 'min_samples_split': 3}
# 0.866 (+/-0.141) for {'max_depth': 10, 'max_features': 12, 'max_leaf_nodes': 30, 'min_samples_leaf': 3, 'min_samples_split': 4}
# 0.845 (+/-0.109) for {'max_depth': 10, 'max_features': 12, 'max_leaf_nodes': 30, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.866 (+/-0.135) for {'max_depth': 10, 'max_features': 12, 'max_leaf_nodes': 30, 'min_samples_leaf': 5, 'min_samples_split': 3}
# 0.866 (+/-0.125) for {'max_depth': 10, 'max_features': 12, 'max_leaf_nodes': 30, 'min_samples_leaf': 5, 'min_samples_split': 4}
# 0.831 (+/-0.154) for {'max_depth': 10, 'max_features': 12, 'max_leaf_nodes': 30, 'min_samples_leaf': 7, 'min_samples_split': 2}
# 0.838 (+/-0.137) for {'max_depth': 10, 'max_features': 12, 'max_leaf_nodes': 30, 'min_samples_leaf': 7, 'min_samples_split': 3}
# 0.824 (+/-0.156) for {'max_depth': 10, 'max_features': 12, 'max_leaf_nodes': 30, 'min_samples_leaf': 7, 'min_samples_split': 4}
# 0.859 (+/-0.116) for {'max_depth': 10, 'max_features': 12, 'max_leaf_nodes': 40, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.908 (+/-0.050) for {'max_depth': 10, 'max_features': 12, 'max_leaf_nodes': 40, 'min_samples_leaf': 1, 'min_samples_split': 3}
# 0.908 (+/-0.050) for {'max_depth': 10, 'max_features': 12, 'max_leaf_nodes': 40, 'min_samples_leaf': 1, 'min_samples_split': 4}
# 0.866 (+/-0.141) for {'max_depth': 10, 'max_features': 12, 'max_leaf_nodes': 40, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.859 (+/-0.126) for {'max_depth': 10, 'max_features': 12, 'max_leaf_nodes': 40, 'min_samples_leaf': 3, 'min_samples_split': 3}
# 0.880 (+/-0.149) for {'max_depth': 10, 'max_features': 12, 'max_leaf_nodes': 40, 'min_samples_leaf': 3, 'min_samples_split': 4}
# 0.852 (+/-0.118) for {'max_depth': 10, 'max_features': 12, 'max_leaf_nodes': 40, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.845 (+/-0.134) for {'max_depth': 10, 'max_features': 12, 'max_leaf_nodes': 40, 'min_samples_leaf': 5, 'min_samples_split': 3}
# 0.838 (+/-0.088) for {'max_depth': 10, 'max_features': 12, 'max_leaf_nodes': 40, 'min_samples_leaf': 5, 'min_samples_split': 4}
# 0.838 (+/-0.161) for {'max_depth': 10, 'max_features': 12, 'max_leaf_nodes': 40, 'min_samples_leaf': 7, 'min_samples_split': 2}
# 0.845 (+/-0.098) for {'max_depth': 10, 'max_features': 12, 'max_leaf_nodes': 40, 'min_samples_leaf': 7, 'min_samples_split': 3}
# 0.845 (+/-0.155) for {'max_depth': 10, 'max_features': 12, 'max_leaf_nodes': 40, 'min_samples_leaf': 7, 'min_samples_split': 4}
# 0.887 (+/-0.135) for {'max_depth': 10, 'max_features': 12, 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.887 (+/-0.074) for {'max_depth': 10, 'max_features': 12, 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 3}
# 0.915 (+/-0.079) for {'max_depth': 10, 'max_features': 12, 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 4}
# 0.873 (+/-0.122) for {'max_depth': 10, 'max_features': 12, 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.852 (+/-0.104) for {'max_depth': 10, 'max_features': 12, 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 3}
# 0.880 (+/-0.098) for {'max_depth': 10, 'max_features': 12, 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 4}
# 0.880 (+/-0.115) for {'max_depth': 10, 'max_features': 12, 'max_leaf_nodes': 50, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.852 (+/-0.114) for {'max_depth': 10, 'max_features': 12, 'max_leaf_nodes': 50, 'min_samples_leaf': 5, 'min_samples_split': 3}
# 0.859 (+/-0.090) for {'max_depth': 10, 'max_features': 12, 'max_leaf_nodes': 50, 'min_samples_leaf': 5, 'min_samples_split': 4}
# 0.852 (+/-0.116) for {'max_depth': 10, 'max_features': 12, 'max_leaf_nodes': 50, 'min_samples_leaf': 7, 'min_samples_split': 2}
# 0.831 (+/-0.140) for {'max_depth': 10, 'max_features': 12, 'max_leaf_nodes': 50, 'min_samples_leaf': 7, 'min_samples_split': 3}
# 0.817 (+/-0.110) for {'max_depth': 10, 'max_features': 12, 'max_leaf_nodes': 50, 'min_samples_leaf': 7, 'min_samples_split': 4}
# 0.908 (+/-0.103) for {'max_depth': 20, 'max_features': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.930 (+/-0.118) for {'max_depth': 20, 'max_features': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 3}
# 0.873 (+/-0.073) for {'max_depth': 20, 'max_features': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 4}
# 0.887 (+/-0.084) for {'max_depth': 20, 'max_features': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.866 (+/-0.157) for {'max_depth': 20, 'max_features': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 3, 'min_samples_split': 3}
# 0.901 (+/-0.109) for {'max_depth': 20, 'max_features': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 3, 'min_samples_split': 4}
# 0.859 (+/-0.140) for {'max_depth': 20, 'max_features': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.852 (+/-0.064) for {'max_depth': 20, 'max_features': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 3}
# 0.838 (+/-0.143) for {'max_depth': 20, 'max_features': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 4}
# 0.824 (+/-0.116) for {'max_depth': 20, 'max_features': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 7, 'min_samples_split': 2}
# 0.852 (+/-0.109) for {'max_depth': 20, 'max_features': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 7, 'min_samples_split': 3}
# 0.845 (+/-0.127) for {'max_depth': 20, 'max_features': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 7, 'min_samples_split': 4}
# 0.908 (+/-0.056) for {'max_depth': 20, 'max_features': 5, 'max_leaf_nodes': 30, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.852 (+/-0.163) for {'max_depth': 20, 'max_features': 5, 'max_leaf_nodes': 30, 'min_samples_leaf': 1, 'min_samples_split': 3}
# 0.894 (+/-0.113) for {'max_depth': 20, 'max_features': 5, 'max_leaf_nodes': 30, 'min_samples_leaf': 1, 'min_samples_split': 4}
# 0.887 (+/-0.140) for {'max_depth': 20, 'max_features': 5, 'max_leaf_nodes': 30, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.915 (+/-0.086) for {'max_depth': 20, 'max_features': 5, 'max_leaf_nodes': 30, 'min_samples_leaf': 3, 'min_samples_split': 3}
# 0.901 (+/-0.078) for {'max_depth': 20, 'max_features': 5, 'max_leaf_nodes': 30, 'min_samples_leaf': 3, 'min_samples_split': 4}
# 0.845 (+/-0.132) for {'max_depth': 20, 'max_features': 5, 'max_leaf_nodes': 30, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.845 (+/-0.107) for {'max_depth': 20, 'max_features': 5, 'max_leaf_nodes': 30, 'min_samples_leaf': 5, 'min_samples_split': 3}
# 0.852 (+/-0.109) for {'max_depth': 20, 'max_features': 5, 'max_leaf_nodes': 30, 'min_samples_leaf': 5, 'min_samples_split': 4}
# 0.838 (+/-0.146) for {'max_depth': 20, 'max_features': 5, 'max_leaf_nodes': 30, 'min_samples_leaf': 7, 'min_samples_split': 2}
# 0.845 (+/-0.090) for {'max_depth': 20, 'max_features': 5, 'max_leaf_nodes': 30, 'min_samples_leaf': 7, 'min_samples_split': 3}
# 0.859 (+/-0.103) for {'max_depth': 20, 'max_features': 5, 'max_leaf_nodes': 30, 'min_samples_leaf': 7, 'min_samples_split': 4}
# 0.873 (+/-0.121) for {'max_depth': 20, 'max_features': 5, 'max_leaf_nodes': 40, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.894 (+/-0.119) for {'max_depth': 20, 'max_features': 5, 'max_leaf_nodes': 40, 'min_samples_leaf': 1, 'min_samples_split': 3}
# 0.887 (+/-0.133) for {'max_depth': 20, 'max_features': 5, 'max_leaf_nodes': 40, 'min_samples_leaf': 1, 'min_samples_split': 4}
# 0.880 (+/-0.125) for {'max_depth': 20, 'max_features': 5, 'max_leaf_nodes': 40, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.937 (+/-0.089) for {'max_depth': 20, 'max_features': 5, 'max_leaf_nodes': 40, 'min_samples_leaf': 3, 'min_samples_split': 3}
# 0.873 (+/-0.075) for {'max_depth': 20, 'max_features': 5, 'max_leaf_nodes': 40, 'min_samples_leaf': 3, 'min_samples_split': 4}
# 0.845 (+/-0.152) for {'max_depth': 20, 'max_features': 5, 'max_leaf_nodes': 40, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.901 (+/-0.028) for {'max_depth': 20, 'max_features': 5, 'max_leaf_nodes': 40, 'min_samples_leaf': 5, 'min_samples_split': 3}
# 0.831 (+/-0.100) for {'max_depth': 20, 'max_features': 5, 'max_leaf_nodes': 40, 'min_samples_leaf': 5, 'min_samples_split': 4}
# 0.873 (+/-0.087) for {'max_depth': 20, 'max_features': 5, 'max_leaf_nodes': 40, 'min_samples_leaf': 7, 'min_samples_split': 2}
# 0.838 (+/-0.069) for {'max_depth': 20, 'max_features': 5, 'max_leaf_nodes': 40, 'min_samples_leaf': 7, 'min_samples_split': 3}
# 0.880 (+/-0.093) for {'max_depth': 20, 'max_features': 5, 'max_leaf_nodes': 40, 'min_samples_leaf': 7, 'min_samples_split': 4}
# 0.923 (+/-0.101) for {'max_depth': 20, 'max_features': 5, 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.901 (+/-0.121) for {'max_depth': 20, 'max_features': 5, 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 3}
# 0.887 (+/-0.104) for {'max_depth': 20, 'max_features': 5, 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 4}
# 0.873 (+/-0.100) for {'max_depth': 20, 'max_features': 5, 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.887 (+/-0.084) for {'max_depth': 20, 'max_features': 5, 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 3}
# 0.866 (+/-0.254) for {'max_depth': 20, 'max_features': 5, 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 4}
# 0.880 (+/-0.100) for {'max_depth': 20, 'max_features': 5, 'max_leaf_nodes': 50, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.873 (+/-0.075) for {'max_depth': 20, 'max_features': 5, 'max_leaf_nodes': 50, 'min_samples_leaf': 5, 'min_samples_split': 3}
# 0.859 (+/-0.064) for {'max_depth': 20, 'max_features': 5, 'max_leaf_nodes': 50, 'min_samples_leaf': 5, 'min_samples_split': 4}
# 0.852 (+/-0.124) for {'max_depth': 20, 'max_features': 5, 'max_leaf_nodes': 50, 'min_samples_leaf': 7, 'min_samples_split': 2}
# 0.845 (+/-0.098) for {'max_depth': 20, 'max_features': 5, 'max_leaf_nodes': 50, 'min_samples_leaf': 7, 'min_samples_split': 3}
# 0.852 (+/-0.131) for {'max_depth': 20, 'max_features': 5, 'max_leaf_nodes': 50, 'min_samples_leaf': 7, 'min_samples_split': 4}
# 0.880 (+/-0.106) for {'max_depth': 20, 'max_features': 7, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.944 (+/-0.095) for {'max_depth': 20, 'max_features': 7, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 3}
# 0.894 (+/-0.140) for {'max_depth': 20, 'max_features': 7, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 4}
# 0.852 (+/-0.032) for {'max_depth': 20, 'max_features': 7, 'max_leaf_nodes': 20, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.866 (+/-0.124) for {'max_depth': 20, 'max_features': 7, 'max_leaf_nodes': 20, 'min_samples_leaf': 3, 'min_samples_split': 3}
# 0.852 (+/-0.141) for {'max_depth': 20, 'max_features': 7, 'max_leaf_nodes': 20, 'min_samples_leaf': 3, 'min_samples_split': 4}
# 0.859 (+/-0.093) for {'max_depth': 20, 'max_features': 7, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.887 (+/-0.129) for {'max_depth': 20, 'max_features': 7, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 3}
# 0.887 (+/-0.125) for {'max_depth': 20, 'max_features': 7, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 4}
# 0.838 (+/-0.137) for {'max_depth': 20, 'max_features': 7, 'max_leaf_nodes': 20, 'min_samples_leaf': 7, 'min_samples_split': 2}
# 0.845 (+/-0.105) for {'max_depth': 20, 'max_features': 7, 'max_leaf_nodes': 20, 'min_samples_leaf': 7, 'min_samples_split': 3}
# 0.866 (+/-0.093) for {'max_depth': 20, 'max_features': 7, 'max_leaf_nodes': 20, 'min_samples_leaf': 7, 'min_samples_split': 4}
# 0.873 (+/-0.094) for {'max_depth': 20, 'max_features': 7, 'max_leaf_nodes': 30, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.894 (+/-0.096) for {'max_depth': 20, 'max_features': 7, 'max_leaf_nodes': 30, 'min_samples_leaf': 1, 'min_samples_split': 3}
# 0.930 (+/-0.117) for {'max_depth': 20, 'max_features': 7, 'max_leaf_nodes': 30, 'min_samples_leaf': 1, 'min_samples_split': 4}
# 0.859 (+/-0.090) for {'max_depth': 20, 'max_features': 7, 'max_leaf_nodes': 30, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.894 (+/-0.087) for {'max_depth': 20, 'max_features': 7, 'max_leaf_nodes': 30, 'min_samples_leaf': 3, 'min_samples_split': 3}
# 0.880 (+/-0.120) for {'max_depth': 20, 'max_features': 7, 'max_leaf_nodes': 30, 'min_samples_leaf': 3, 'min_samples_split': 4}
# 0.859 (+/-0.117) for {'max_depth': 20, 'max_features': 7, 'max_leaf_nodes': 30, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.866 (+/-0.119) for {'max_depth': 20, 'max_features': 7, 'max_leaf_nodes': 30, 'min_samples_leaf': 5, 'min_samples_split': 3}
# 0.831 (+/-0.095) for {'max_depth': 20, 'max_features': 7, 'max_leaf_nodes': 30, 'min_samples_leaf': 5, 'min_samples_split': 4}
# 0.866 (+/-0.137) for {'max_depth': 20, 'max_features': 7, 'max_leaf_nodes': 30, 'min_samples_leaf': 7, 'min_samples_split': 2}
# 0.859 (+/-0.109) for {'max_depth': 20, 'max_features': 7, 'max_leaf_nodes': 30, 'min_samples_leaf': 7, 'min_samples_split': 3}
# 0.859 (+/-0.079) for {'max_depth': 20, 'max_features': 7, 'max_leaf_nodes': 30, 'min_samples_leaf': 7, 'min_samples_split': 4}
# 0.887 (+/-0.064) for {'max_depth': 20, 'max_features': 7, 'max_leaf_nodes': 40, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.880 (+/-0.093) for {'max_depth': 20, 'max_features': 7, 'max_leaf_nodes': 40, 'min_samples_leaf': 1, 'min_samples_split': 3}
# 0.908 (+/-0.067) for {'max_depth': 20, 'max_features': 7, 'max_leaf_nodes': 40, 'min_samples_leaf': 1, 'min_samples_split': 4}
# 0.894 (+/-0.113) for {'max_depth': 20, 'max_features': 7, 'max_leaf_nodes': 40, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.894 (+/-0.075) for {'max_depth': 20, 'max_features': 7, 'max_leaf_nodes': 40, 'min_samples_leaf': 3, 'min_samples_split': 3}
# 0.880 (+/-0.102) for {'max_depth': 20, 'max_features': 7, 'max_leaf_nodes': 40, 'min_samples_leaf': 3, 'min_samples_split': 4}
# 0.859 (+/-0.140) for {'max_depth': 20, 'max_features': 7, 'max_leaf_nodes': 40, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.817 (+/-0.105) for {'max_depth': 20, 'max_features': 7, 'max_leaf_nodes': 40, 'min_samples_leaf': 5, 'min_samples_split': 3}
# 0.838 (+/-0.111) for {'max_depth': 20, 'max_features': 7, 'max_leaf_nodes': 40, 'min_samples_leaf': 5, 'min_samples_split': 4}
# 0.859 (+/-0.137) for {'max_depth': 20, 'max_features': 7, 'max_leaf_nodes': 40, 'min_samples_leaf': 7, 'min_samples_split': 2}
# 0.859 (+/-0.177) for {'max_depth': 20, 'max_features': 7, 'max_leaf_nodes': 40, 'min_samples_leaf': 7, 'min_samples_split': 3}
# 0.852 (+/-0.141) for {'max_depth': 20, 'max_features': 7, 'max_leaf_nodes': 40, 'min_samples_leaf': 7, 'min_samples_split': 4}
# 0.930 (+/-0.005) for {'max_depth': 20, 'max_features': 7, 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.908 (+/-0.099) for {'max_depth': 20, 'max_features': 7, 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 3}
# 0.894 (+/-0.043) for {'max_depth': 20, 'max_features': 7, 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 4}
# 0.873 (+/-0.123) for {'max_depth': 20, 'max_features': 7, 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.866 (+/-0.135) for {'max_depth': 20, 'max_features': 7, 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 3}
# 0.887 (+/-0.116) for {'max_depth': 20, 'max_features': 7, 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 4}
# 0.894 (+/-0.111) for {'max_depth': 20, 'max_features': 7, 'max_leaf_nodes': 50, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.894 (+/-0.087) for {'max_depth': 20, 'max_features': 7, 'max_leaf_nodes': 50, 'min_samples_leaf': 5, 'min_samples_split': 3}
# 0.838 (+/-0.195) for {'max_depth': 20, 'max_features': 7, 'max_leaf_nodes': 50, 'min_samples_leaf': 5, 'min_samples_split': 4}
# 0.838 (+/-0.126) for {'max_depth': 20, 'max_features': 7, 'max_leaf_nodes': 50, 'min_samples_leaf': 7, 'min_samples_split': 2}
# 0.859 (+/-0.125) for {'max_depth': 20, 'max_features': 7, 'max_leaf_nodes': 50, 'min_samples_leaf': 7, 'min_samples_split': 3}
# 0.852 (+/-0.120) for {'max_depth': 20, 'max_features': 7, 'max_leaf_nodes': 50, 'min_samples_leaf': 7, 'min_samples_split': 4}
# 0.915 (+/-0.090) for {'max_depth': 20, 'max_features': 8, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.923 (+/-0.049) for {'max_depth': 20, 'max_features': 8, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 3}
# 0.880 (+/-0.041) for {'max_depth': 20, 'max_features': 8, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 4}
# 0.908 (+/-0.100) for {'max_depth': 20, 'max_features': 8, 'max_leaf_nodes': 20, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.894 (+/-0.140) for {'max_depth': 20, 'max_features': 8, 'max_leaf_nodes': 20, 'min_samples_leaf': 3, 'min_samples_split': 3}
# 0.887 (+/-0.080) for {'max_depth': 20, 'max_features': 8, 'max_leaf_nodes': 20, 'min_samples_leaf': 3, 'min_samples_split': 4}
# 0.894 (+/-0.062) for {'max_depth': 20, 'max_features': 8, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.845 (+/-0.130) for {'max_depth': 20, 'max_features': 8, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 3}
# 0.845 (+/-0.162) for {'max_depth': 20, 'max_features': 8, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 4}
# 0.838 (+/-0.127) for {'max_depth': 20, 'max_features': 8, 'max_leaf_nodes': 20, 'min_samples_leaf': 7, 'min_samples_split': 2}
# 0.838 (+/-0.157) for {'max_depth': 20, 'max_features': 8, 'max_leaf_nodes': 20, 'min_samples_leaf': 7, 'min_samples_split': 3}
# 0.817 (+/-0.110) for {'max_depth': 20, 'max_features': 8, 'max_leaf_nodes': 20, 'min_samples_leaf': 7, 'min_samples_split': 4}
# 0.887 (+/-0.050) for {'max_depth': 20, 'max_features': 8, 'max_leaf_nodes': 30, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.887 (+/-0.094) for {'max_depth': 20, 'max_features': 8, 'max_leaf_nodes': 30, 'min_samples_leaf': 1, 'min_samples_split': 3}
# 0.937 (+/-0.071) for {'max_depth': 20, 'max_features': 8, 'max_leaf_nodes': 30, 'min_samples_leaf': 1, 'min_samples_split': 4}
# 0.894 (+/-0.075) for {'max_depth': 20, 'max_features': 8, 'max_leaf_nodes': 30, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.901 (+/-0.094) for {'max_depth': 20, 'max_features': 8, 'max_leaf_nodes': 30, 'min_samples_leaf': 3, 'min_samples_split': 3}
# 0.915 (+/-0.078) for {'max_depth': 20, 'max_features': 8, 'max_leaf_nodes': 30, 'min_samples_leaf': 3, 'min_samples_split': 4}
# 0.845 (+/-0.099) for {'max_depth': 20, 'max_features': 8, 'max_leaf_nodes': 30, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.810 (+/-0.109) for {'max_depth': 20, 'max_features': 8, 'max_leaf_nodes': 30, 'min_samples_leaf': 5, 'min_samples_split': 3}
# 0.859 (+/-0.100) for {'max_depth': 20, 'max_features': 8, 'max_leaf_nodes': 30, 'min_samples_leaf': 5, 'min_samples_split': 4}
# 0.845 (+/-0.106) for {'max_depth': 20, 'max_features': 8, 'max_leaf_nodes': 30, 'min_samples_leaf': 7, 'min_samples_split': 2}
# 0.810 (+/-0.092) for {'max_depth': 20, 'max_features': 8, 'max_leaf_nodes': 30, 'min_samples_leaf': 7, 'min_samples_split': 3}
# 0.817 (+/-0.114) for {'max_depth': 20, 'max_features': 8, 'max_leaf_nodes': 30, 'min_samples_leaf': 7, 'min_samples_split': 4}
# 0.894 (+/-0.140) for {'max_depth': 20, 'max_features': 8, 'max_leaf_nodes': 40, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.901 (+/-0.156) for {'max_depth': 20, 'max_features': 8, 'max_leaf_nodes': 40, 'min_samples_leaf': 1, 'min_samples_split': 3}
# 0.923 (+/-0.138) for {'max_depth': 20, 'max_features': 8, 'max_leaf_nodes': 40, 'min_samples_leaf': 1, 'min_samples_split': 4}
# 0.880 (+/-0.166) for {'max_depth': 20, 'max_features': 8, 'max_leaf_nodes': 40, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.859 (+/-0.120) for {'max_depth': 20, 'max_features': 8, 'max_leaf_nodes': 40, 'min_samples_leaf': 3, 'min_samples_split': 3}
# 0.887 (+/-0.120) for {'max_depth': 20, 'max_features': 8, 'max_leaf_nodes': 40, 'min_samples_leaf': 3, 'min_samples_split': 4}
# 0.873 (+/-0.142) for {'max_depth': 20, 'max_features': 8, 'max_leaf_nodes': 40, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.866 (+/-0.183) for {'max_depth': 20, 'max_features': 8, 'max_leaf_nodes': 40, 'min_samples_leaf': 5, 'min_samples_split': 3}
# 0.859 (+/-0.123) for {'max_depth': 20, 'max_features': 8, 'max_leaf_nodes': 40, 'min_samples_leaf': 5, 'min_samples_split': 4}
# 0.873 (+/-0.131) for {'max_depth': 20, 'max_features': 8, 'max_leaf_nodes': 40, 'min_samples_leaf': 7, 'min_samples_split': 2}
# 0.873 (+/-0.069) for {'max_depth': 20, 'max_features': 8, 'max_leaf_nodes': 40, 'min_samples_leaf': 7, 'min_samples_split': 3}
# 0.845 (+/-0.087) for {'max_depth': 20, 'max_features': 8, 'max_leaf_nodes': 40, 'min_samples_leaf': 7, 'min_samples_split': 4}
# 0.908 (+/-0.145) for {'max_depth': 20, 'max_features': 8, 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.880 (+/-0.160) for {'max_depth': 20, 'max_features': 8, 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 3}
# 0.915 (+/-0.096) for {'max_depth': 20, 'max_features': 8, 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 4}
# ...
# 0.873 (+/-0.105) for {'max_depth': 40, 'max_features': 8, 'max_leaf_nodes': 30, 'min_samples_leaf': 7, 'min_samples_split': 4}
# 0.901 (+/-0.170) for {'max_depth': 40, 'max_features': 8, 'max_leaf_nodes': 40, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.887 (+/-0.104) for {'max_depth': 40, 'max_features': 8, 'max_leaf_nodes': 40, 'min_samples_leaf': 1, 'min_samples_split': 3}
# 0.873 (+/-0.137) for {'max_depth': 40, 'max_features': 8, 'max_leaf_nodes': 40, 'min_samples_leaf': 1, 'min_samples_split': 4}
# 0.894 (+/-0.148) for {'max_depth': 40, 'max_features': 8, 'max_leaf_nodes': 40, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.908 (+/-0.070) for {'max_depth': 40, 'max_features': 8, 'max_leaf_nodes': 40, 'min_samples_leaf': 3, 'min_samples_split': 3}
# 0.887 (+/-0.052) for {'max_depth': 40, 'max_features': 8, 'max_leaf_nodes': 40, 'min_samples_leaf': 3, 'min_samples_split': 4}
# 0.866 (+/-0.118) for {'max_depth': 40, 'max_features': 8, 'max_leaf_nodes': 40, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.873 (+/-0.073) for {'max_depth': 40, 'max_features': 8, 'max_leaf_nodes': 40, 'min_samples_leaf': 5, 'min_samples_split': 3}
# 0.873 (+/-0.135) for {'max_depth': 40, 'max_features': 8, 'max_leaf_nodes': 40, 'min_samples_leaf': 5, 'min_samples_split': 4}
# 0.880 (+/-0.117) for {'max_depth': 40, 'max_features': 8, 'max_leaf_nodes': 40, 'min_samples_leaf': 7, 'min_samples_split': 2}
# 0.852 (+/-0.114) for {'max_depth': 40, 'max_features': 8, 'max_leaf_nodes': 40, 'min_samples_leaf': 7, 'min_samples_split': 3}
# 0.873 (+/-0.076) for {'max_depth': 40, 'max_features': 8, 'max_leaf_nodes': 40, 'min_samples_leaf': 7, 'min_samples_split': 4}
# 0.887 (+/-0.110) for {'max_depth': 40, 'max_features': 8, 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.894 (+/-0.056) for {'max_depth': 40, 'max_features': 8, 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 3}
# 0.880 (+/-0.153) for {'max_depth': 40, 'max_features': 8, 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 4}
# 0.923 (+/-0.064) for {'max_depth': 40, 'max_features': 8, 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.873 (+/-0.130) for {'max_depth': 40, 'max_features': 8, 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 3}
# 0.824 (+/-0.077) for {'max_depth': 40, 'max_features': 8, 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 4}
# 0.901 (+/-0.119) for {'max_depth': 40, 'max_features': 8, 'max_leaf_nodes': 50, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.915 (+/-0.051) for {'max_depth': 40, 'max_features': 8, 'max_leaf_nodes': 50, 'min_samples_leaf': 5, 'min_samples_split': 3}
# 0.845 (+/-0.104) for {'max_depth': 40, 'max_features': 8, 'max_leaf_nodes': 50, 'min_samples_leaf': 5, 'min_samples_split': 4}
# 0.845 (+/-0.105) for {'max_depth': 40, 'max_features': 8, 'max_leaf_nodes': 50, 'min_samples_leaf': 7, 'min_samples_split': 2}
# 0.887 (+/-0.022) for {'max_depth': 40, 'max_features': 8, 'max_leaf_nodes': 50, 'min_samples_leaf': 7, 'min_samples_split': 3}
# 0.838 (+/-0.066) for {'max_depth': 40, 'max_features': 8, 'max_leaf_nodes': 50, 'min_samples_leaf': 7, 'min_samples_split': 4}
# 0.930 (+/-0.133) for {'max_depth': 40, 'max_features': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.901 (+/-0.139) for {'max_depth': 40, 'max_features': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 3}
# 0.887 (+/-0.162) for {'max_depth': 40, 'max_features': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 4}
# 0.859 (+/-0.119) for {'max_depth': 40, 'max_features': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.838 (+/-0.146) for {'max_depth': 40, 'max_features': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 3, 'min_samples_split': 3}
# 0.901 (+/-0.053) for {'max_depth': 40, 'max_features': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 3, 'min_samples_split': 4}
# 0.852 (+/-0.110) for {'max_depth': 40, 'max_features': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.852 (+/-0.154) for {'max_depth': 40, 'max_features': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 3}
# 0.838 (+/-0.180) for {'max_depth': 40, 'max_features': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 4}
# 0.866 (+/-0.142) for {'max_depth': 40, 'max_features': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 7, 'min_samples_split': 2}
# 0.824 (+/-0.122) for {'max_depth': 40, 'max_features': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 7, 'min_samples_split': 3}
# 0.831 (+/-0.117) for {'max_depth': 40, 'max_features': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 7, 'min_samples_split': 4}
# 0.887 (+/-0.062) for {'max_depth': 40, 'max_features': 10, 'max_leaf_nodes': 30, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.923 (+/-0.080) for {'max_depth': 40, 'max_features': 10, 'max_leaf_nodes': 30, 'min_samples_leaf': 1, 'min_samples_split': 3}
# 0.930 (+/-0.077) for {'max_depth': 40, 'max_features': 10, 'max_leaf_nodes': 30, 'min_samples_leaf': 1, 'min_samples_split': 4}
# 0.873 (+/-0.108) for {'max_depth': 40, 'max_features': 10, 'max_leaf_nodes': 30, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.887 (+/-0.134) for {'max_depth': 40, 'max_features': 10, 'max_leaf_nodes': 30, 'min_samples_leaf': 3, 'min_samples_split': 3}
# 0.915 (+/-0.093) for {'max_depth': 40, 'max_features': 10, 'max_leaf_nodes': 30, 'min_samples_leaf': 3, 'min_samples_split': 4}
# 0.859 (+/-0.083) for {'max_depth': 40, 'max_features': 10, 'max_leaf_nodes': 30, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.873 (+/-0.126) for {'max_depth': 40, 'max_features': 10, 'max_leaf_nodes': 30, 'min_samples_leaf': 5, 'min_samples_split': 3}
# 0.894 (+/-0.090) for {'max_depth': 40, 'max_features': 10, 'max_leaf_nodes': 30, 'min_samples_leaf': 5, 'min_samples_split': 4}
# 0.894 (+/-0.151) for {'max_depth': 40, 'max_features': 10, 'max_leaf_nodes': 30, 'min_samples_leaf': 7, 'min_samples_split': 2}
# 0.838 (+/-0.154) for {'max_depth': 40, 'max_features': 10, 'max_leaf_nodes': 30, 'min_samples_leaf': 7, 'min_samples_split': 3}
# 0.824 (+/-0.122) for {'max_depth': 40, 'max_features': 10, 'max_leaf_nodes': 30, 'min_samples_leaf': 7, 'min_samples_split': 4}
# 0.908 (+/-0.070) for {'max_depth': 40, 'max_features': 10, 'max_leaf_nodes': 40, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.930 (+/-0.075) for {'max_depth': 40, 'max_features': 10, 'max_leaf_nodes': 40, 'min_samples_leaf': 1, 'min_samples_split': 3}
# 0.915 (+/-0.069) for {'max_depth': 40, 'max_features': 10, 'max_leaf_nodes': 40, 'min_samples_leaf': 1, 'min_samples_split': 4}
# 0.894 (+/-0.122) for {'max_depth': 40, 'max_features': 10, 'max_leaf_nodes': 40, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.894 (+/-0.059) for {'max_depth': 40, 'max_features': 10, 'max_leaf_nodes': 40, 'min_samples_leaf': 3, 'min_samples_split': 3}
# 0.873 (+/-0.139) for {'max_depth': 40, 'max_features': 10, 'max_leaf_nodes': 40, 'min_samples_leaf': 3, 'min_samples_split': 4}
# 0.845 (+/-0.104) for {'max_depth': 40, 'max_features': 10, 'max_leaf_nodes': 40, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.859 (+/-0.137) for {'max_depth': 40, 'max_features': 10, 'max_leaf_nodes': 40, 'min_samples_leaf': 5, 'min_samples_split': 3}
# 0.817 (+/-0.096) for {'max_depth': 40, 'max_features': 10, 'max_leaf_nodes': 40, 'min_samples_leaf': 5, 'min_samples_split': 4}
# 0.845 (+/-0.098) for {'max_depth': 40, 'max_features': 10, 'max_leaf_nodes': 40, 'min_samples_leaf': 7, 'min_samples_split': 2}
# 0.880 (+/-0.135) for {'max_depth': 40, 'max_features': 10, 'max_leaf_nodes': 40, 'min_samples_leaf': 7, 'min_samples_split': 3}
# 0.852 (+/-0.132) for {'max_depth': 40, 'max_features': 10, 'max_leaf_nodes': 40, 'min_samples_leaf': 7, 'min_samples_split': 4}
# 0.887 (+/-0.130) for {'max_depth': 40, 'max_features': 10, 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.908 (+/-0.030) for {'max_depth': 40, 'max_features': 10, 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 3}
# 0.901 (+/-0.071) for {'max_depth': 40, 'max_features': 10, 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 4}
# 0.859 (+/-0.173) for {'max_depth': 40, 'max_features': 10, 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.894 (+/-0.094) for {'max_depth': 40, 'max_features': 10, 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 3}
# 0.915 (+/-0.093) for {'max_depth': 40, 'max_features': 10, 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 4}
# 0.845 (+/-0.117) for {'max_depth': 40, 'max_features': 10, 'max_leaf_nodes': 50, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.852 (+/-0.116) for {'max_depth': 40, 'max_features': 10, 'max_leaf_nodes': 50, 'min_samples_leaf': 5, 'min_samples_split': 3}
# 0.810 (+/-0.159) for {'max_depth': 40, 'max_features': 10, 'max_leaf_nodes': 50, 'min_samples_leaf': 5, 'min_samples_split': 4}
# 0.789 (+/-0.079) for {'max_depth': 40, 'max_features': 10, 'max_leaf_nodes': 50, 'min_samples_leaf': 7, 'min_samples_split': 2}
# 0.845 (+/-0.098) for {'max_depth': 40, 'max_features': 10, 'max_leaf_nodes': 50, 'min_samples_leaf': 7, 'min_samples_split': 3}
# 0.831 (+/-0.095) for {'max_depth': 40, 'max_features': 10, 'max_leaf_nodes': 50, 'min_samples_leaf': 7, 'min_samples_split': 4}
# 0.901 (+/-0.089) for {'max_depth': 40, 'max_features': 12, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.894 (+/-0.062) for {'max_depth': 40, 'max_features': 12, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 3}
# 0.901 (+/-0.113) for {'max_depth': 40, 'max_features': 12, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 4}
# 0.894 (+/-0.102) for {'max_depth': 40, 'max_features': 12, 'max_leaf_nodes': 20, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.880 (+/-0.125) for {'max_depth': 40, 'max_features': 12, 'max_leaf_nodes': 20, 'min_samples_leaf': 3, 'min_samples_split': 3}
# 0.880 (+/-0.108) for {'max_depth': 40, 'max_features': 12, 'max_leaf_nodes': 20, 'min_samples_leaf': 3, 'min_samples_split': 4}
# 0.824 (+/-0.171) for {'max_depth': 40, 'max_features': 12, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.859 (+/-0.136) for {'max_depth': 40, 'max_features': 12, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 3}
# 0.852 (+/-0.109) for {'max_depth': 40, 'max_features': 12, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 4}
# 0.845 (+/-0.151) for {'max_depth': 40, 'max_features': 12, 'max_leaf_nodes': 20, 'min_samples_leaf': 7, 'min_samples_split': 2}
# 0.831 (+/-0.140) for {'max_depth': 40, 'max_features': 12, 'max_leaf_nodes': 20, 'min_samples_leaf': 7, 'min_samples_split': 3}
# 0.824 (+/-0.122) for {'max_depth': 40, 'max_features': 12, 'max_leaf_nodes': 20, 'min_samples_leaf': 7, 'min_samples_split': 4}
# 0.873 (+/-0.113) for {'max_depth': 40, 'max_features': 12, 'max_leaf_nodes': 30, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.887 (+/-0.096) for {'max_depth': 40, 'max_features': 12, 'max_leaf_nodes': 30, 'min_samples_leaf': 1, 'min_samples_split': 3}
# 0.901 (+/-0.088) for {'max_depth': 40, 'max_features': 12, 'max_leaf_nodes': 30, 'min_samples_leaf': 1, 'min_samples_split': 4}
# 0.880 (+/-0.115) for {'max_depth': 40, 'max_features': 12, 'max_leaf_nodes': 30, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.866 (+/-0.172) for {'max_depth': 40, 'max_features': 12, 'max_leaf_nodes': 30, 'min_samples_leaf': 3, 'min_samples_split': 3}
# 0.859 (+/-0.123) for {'max_depth': 40, 'max_features': 12, 'max_leaf_nodes': 30, 'min_samples_leaf': 3, 'min_samples_split': 4}
# 0.852 (+/-0.135) for {'max_depth': 40, 'max_features': 12, 'max_leaf_nodes': 30, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.852 (+/-0.114) for {'max_depth': 40, 'max_features': 12, 'max_leaf_nodes': 30, 'min_samples_leaf': 5, 'min_samples_split': 3}
# 0.852 (+/-0.109) for {'max_depth': 40, 'max_features': 12, 'max_leaf_nodes': 30, 'min_samples_leaf': 5, 'min_samples_split': 4}
# 0.803 (+/-0.082) for {'max_depth': 40, 'max_features': 12, 'max_leaf_nodes': 30, 'min_samples_leaf': 7, 'min_samples_split': 2}
# 0.831 (+/-0.154) for {'max_depth': 40, 'max_features': 12, 'max_leaf_nodes': 30, 'min_samples_leaf': 7, 'min_samples_split': 3}
# 0.831 (+/-0.140) for {'max_depth': 40, 'max_features': 12, 'max_leaf_nodes': 30, 'min_samples_leaf': 7, 'min_samples_split': 4}
# 0.873 (+/-0.094) for {'max_depth': 40, 'max_features': 12, 'max_leaf_nodes': 40, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.901 (+/-0.028) for {'max_depth': 40, 'max_features': 12, 'max_leaf_nodes': 40, 'min_samples_leaf': 1, 'min_samples_split': 3}
# 0.908 (+/-0.056) for {'max_depth': 40, 'max_features': 12, 'max_leaf_nodes': 40, 'min_samples_leaf': 1, 'min_samples_split': 4}
# 0.866 (+/-0.136) for {'max_depth': 40, 'max_features': 12, 'max_leaf_nodes': 40, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.915 (+/-0.096) for {'max_depth': 40, 'max_features': 12, 'max_leaf_nodes': 40, 'min_samples_leaf': 3, 'min_samples_split': 3}
# 0.866 (+/-0.104) for {'max_depth': 40, 'max_features': 12, 'max_leaf_nodes': 40, 'min_samples_leaf': 3, 'min_samples_split': 4}
# 0.803 (+/-0.074) for {'max_depth': 40, 'max_features': 12, 'max_leaf_nodes': 40, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.859 (+/-0.131) for {'max_depth': 40, 'max_features': 12, 'max_leaf_nodes': 40, 'min_samples_leaf': 5, 'min_samples_split': 3}
# 0.866 (+/-0.132) for {'max_depth': 40, 'max_features': 12, 'max_leaf_nodes': 40, 'min_samples_leaf': 5, 'min_samples_split': 4}
# 0.852 (+/-0.141) for {'max_depth': 40, 'max_features': 12, 'max_leaf_nodes': 40, 'min_samples_leaf': 7, 'min_samples_split': 2}
# 0.824 (+/-0.131) for {'max_depth': 40, 'max_features': 12, 'max_leaf_nodes': 40, 'min_samples_leaf': 7, 'min_samples_split': 3}
# 0.831 (+/-0.136) for {'max_depth': 40, 'max_features': 12, 'max_leaf_nodes': 40, 'min_samples_leaf': 7, 'min_samples_split': 4}
# 0.901 (+/-0.078) for {'max_depth': 40, 'max_features': 12, 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.880 (+/-0.123) for {'max_depth': 40, 'max_features': 12, 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 3}
# 0.894 (+/-0.071) for {'max_depth': 40, 'max_features': 12, 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 4}
# 0.880 (+/-0.098) for {'max_depth': 40, 'max_features': 12, 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 2}
# 0.866 (+/-0.112) for {'max_depth': 40, 'max_features': 12, 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 3}
# 0.880 (+/-0.115) for {'max_depth': 40, 'max_features': 12, 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 4}
# 0.845 (+/-0.109) for {'max_depth': 40, 'max_features': 12, 'max_leaf_nodes': 50, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.859 (+/-0.113) for {'max_depth': 40, 'max_features': 12, 'max_leaf_nodes': 50, 'min_samples_leaf': 5, 'min_samples_split': 3}
# 0.873 (+/-0.145) for {'max_depth': 40, 'max_features': 12, 'max_leaf_nodes': 50, 'min_samples_leaf': 5, 'min_samples_split': 4}
# 0.824 (+/-0.122) for {'max_depth': 40, 'max_features': 12, 'max_leaf_nodes': 50, 'min_samples_leaf': 7, 'min_samples_split': 2}
# 0.831 (+/-0.140) for {'max_depth': 40, 'max_features': 12, 'max_leaf_nodes': 50, 'min_samples_leaf': 7, 'min_samples_split': 3}
# 0.824 (+/-0.122) for {'max_depth': 40, 'max_features': 12, 'max_leaf_nodes': 50, 'min_samples_leaf': 7, 'min_samples_split': 4}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.80      1.00      0.89        12
#           1       0.93      0.93      0.93        15
#           2       1.00      0.67      0.80         9
#
# avg / total       0.91      0.89      0.89        36
#
# Detailed confusion matrix:
# [[12  0  0]
#  [ 1 14  0]
#  [ 2  1  6]]
# Accuracy Score:
#
# 0.8888888888888888

# %%
# For Gaussian Naive Bayes Classifier
from sklearn.naive_bayes import GaussianNB
# This is a key step where you define the parameters and their possible values
# that you would like to check.
tuned_parameters = [{} ]

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(GaussianNB(), tuned_parameters, cv=6,
                       scoring='%s' % score)
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred))
    print("Detailed confusion matrix:")
    print(confusion_matrix(y_true, y_pred))
    print("Accuracy Score: \n")
    print(accuracy_score(y_true, y_pred))

    print()
# Out:
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set:
#
# {}
#
# Grid scores on development set:
#
# 0.972 (+/-0.062) for {}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00        12
#           1       1.00      1.00      1.00        15
#           2       1.00      1.00      1.00         9
#
# avg / total       1.00      1.00      1.00        36
#
# Detailed confusion matrix:
# [[12  0  0]
#  [ 0 15  0]
#  [ 0  0  9]]
# Accuracy Score:
#
# 1.0

# %%
# For Logistic Regression model
from sklearn.linear_model import LogisticRegression
# This is a key step where you define the parameters and their possible values
# that you would like to check.
tuned_parameters = [{
    'class_weight':['balanced'],
    'C':[0.5,1.0,5.0,10.0],
#     'max_iter':,
    'multi_class':['ovr'],
    'fit_intercept':[False]
    
} ]

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(LogisticRegression(), tuned_parameters, cv=6,
                       scoring='%s' % score)
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred))
    print("Detailed confusion matrix:")
    print(confusion_matrix(y_true, y_pred))
    print("Accuracy Score: \n")
    print(accuracy_score(y_true, y_pred))

    print()
# Out:
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set:
#
# {'C': 0.5, 'class_weight': 'balanced', 'fit_intercept': False, 'multi_class': 'ovr'}
#
# Grid scores on development set:
#
# 0.951 (+/-0.057) for {'C': 0.5, 'class_weight': 'balanced', 'fit_intercept': False, 'multi_class': 'ovr'}
# 0.951 (+/-0.057) for {'C': 1.0, 'class_weight': 'balanced', 'fit_intercept': False, 'multi_class': 'ovr'}
# 0.937 (+/-0.066) for {'C': 5.0, 'class_weight': 'balanced', 'fit_intercept': False, 'multi_class': 'ovr'}
# 0.937 (+/-0.066) for {'C': 10.0, 'class_weight': 'balanced', 'fit_intercept': False, 'multi_class': 'ovr'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00        12
#           1       0.94      1.00      0.97        15
#           2       1.00      0.89      0.94         9
#
# avg / total       0.97      0.97      0.97        36
#
# Detailed confusion matrix:
# [[12  0  0]
#  [ 0 15  0]
#  [ 0  1  8]]
# Accuracy Score:
#
# 0.9722222222222222

# %%
# For k Nearest Neighbours
from sklearn.neighbors import KNeighborsClassifier
# This is a key step where you define the parameters and their possible values
# that you would like to check.
tuned_parameters = [{'n_neighbors':[2,5,7,9],
'weights':['uniform','distance'],
'algorithm':['ball_tree','kd_tree','brute'],
'p':[1,2,4]}
                    ]

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(KNeighborsClassifier(), tuned_parameters, cv=5,
                       scoring='%s' % score)
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred))
    print("Detailed confusion matrix:")
    print(confusion_matrix(y_true, y_pred))
    print("Accuracy Score: \n")
    print(accuracy_score(y_true, y_pred))

    print()
# Out:
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set:
#
# {'algorithm': 'ball_tree', 'n_neighbors': 2, 'p': 1, 'weights': 'distance'}
#
# Grid scores on development set:
#
# 0.718 (+/-0.154) for {'algorithm': 'ball_tree', 'n_neighbors': 2, 'p': 1, 'weights': 'uniform'}
# 0.824 (+/-0.082) for {'algorithm': 'ball_tree', 'n_neighbors': 2, 'p': 1, 'weights': 'distance'}
# 0.662 (+/-0.128) for {'algorithm': 'ball_tree', 'n_neighbors': 2, 'p': 2, 'weights': 'uniform'}
# 0.732 (+/-0.080) for {'algorithm': 'ball_tree', 'n_neighbors': 2, 'p': 2, 'weights': 'distance'}
# 0.662 (+/-0.133) for {'algorithm': 'ball_tree', 'n_neighbors': 2, 'p': 4, 'weights': 'uniform'}
# 0.683 (+/-0.118) for {'algorithm': 'ball_tree', 'n_neighbors': 2, 'p': 4, 'weights': 'distance'}
# 0.761 (+/-0.120) for {'algorithm': 'ball_tree', 'n_neighbors': 5, 'p': 1, 'weights': 'uniform'}
# 0.803 (+/-0.109) for {'algorithm': 'ball_tree', 'n_neighbors': 5, 'p': 1, 'weights': 'distance'}
# 0.690 (+/-0.141) for {'algorithm': 'ball_tree', 'n_neighbors': 5, 'p': 2, 'weights': 'uniform'}
# 0.739 (+/-0.059) for {'algorithm': 'ball_tree', 'n_neighbors': 5, 'p': 2, 'weights': 'distance'}
# 0.690 (+/-0.141) for {'algorithm': 'ball_tree', 'n_neighbors': 5, 'p': 4, 'weights': 'uniform'}
# 0.711 (+/-0.081) for {'algorithm': 'ball_tree', 'n_neighbors': 5, 'p': 4, 'weights': 'distance'}
# 0.754 (+/-0.123) for {'algorithm': 'ball_tree', 'n_neighbors': 7, 'p': 1, 'weights': 'uniform'}
# 0.789 (+/-0.140) for {'algorithm': 'ball_tree', 'n_neighbors': 7, 'p': 1, 'weights': 'distance'}
# 0.697 (+/-0.139) for {'algorithm': 'ball_tree', 'n_neighbors': 7, 'p': 2, 'weights': 'uniform'}
# 0.725 (+/-0.108) for {'algorithm': 'ball_tree', 'n_neighbors': 7, 'p': 2, 'weights': 'distance'}
# 0.690 (+/-0.159) for {'algorithm': 'ball_tree', 'n_neighbors': 7, 'p': 4, 'weights': 'uniform'}
# 0.697 (+/-0.100) for {'algorithm': 'ball_tree', 'n_neighbors': 7, 'p': 4, 'weights': 'distance'}
# 0.746 (+/-0.140) for {'algorithm': 'ball_tree', 'n_neighbors': 9, 'p': 1, 'weights': 'uniform'}
# 0.761 (+/-0.139) for {'algorithm': 'ball_tree', 'n_neighbors': 9, 'p': 1, 'weights': 'distance'}
# 0.711 (+/-0.170) for {'algorithm': 'ball_tree', 'n_neighbors': 9, 'p': 2, 'weights': 'uniform'}
# 0.725 (+/-0.080) for {'algorithm': 'ball_tree', 'n_neighbors': 9, 'p': 2, 'weights': 'distance'}
# 0.725 (+/-0.178) for {'algorithm': 'ball_tree', 'n_neighbors': 9, 'p': 4, 'weights': 'uniform'}
# 0.718 (+/-0.073) for {'algorithm': 'ball_tree', 'n_neighbors': 9, 'p': 4, 'weights': 'distance'}
# 0.718 (+/-0.154) for {'algorithm': 'kd_tree', 'n_neighbors': 2, 'p': 1, 'weights': 'uniform'}
# 0.824 (+/-0.082) for {'algorithm': 'kd_tree', 'n_neighbors': 2, 'p': 1, 'weights': 'distance'}
# 0.662 (+/-0.128) for {'algorithm': 'kd_tree', 'n_neighbors': 2, 'p': 2, 'weights': 'uniform'}
# 0.732 (+/-0.080) for {'algorithm': 'kd_tree', 'n_neighbors': 2, 'p': 2, 'weights': 'distance'}
# 0.662 (+/-0.133) for {'algorithm': 'kd_tree', 'n_neighbors': 2, 'p': 4, 'weights': 'uniform'}
# 0.683 (+/-0.118) for {'algorithm': 'kd_tree', 'n_neighbors': 2, 'p': 4, 'weights': 'distance'}
# 0.761 (+/-0.120) for {'algorithm': 'kd_tree', 'n_neighbors': 5, 'p': 1, 'weights': 'uniform'}
# 0.803 (+/-0.109) for {'algorithm': 'kd_tree', 'n_neighbors': 5, 'p': 1, 'weights': 'distance'}
# 0.690 (+/-0.141) for {'algorithm': 'kd_tree', 'n_neighbors': 5, 'p': 2, 'weights': 'uniform'}
# 0.739 (+/-0.059) for {'algorithm': 'kd_tree', 'n_neighbors': 5, 'p': 2, 'weights': 'distance'}
# 0.690 (+/-0.141) for {'algorithm': 'kd_tree', 'n_neighbors': 5, 'p': 4, 'weights': 'uniform'}
# 0.711 (+/-0.081) for {'algorithm': 'kd_tree', 'n_neighbors': 5, 'p': 4, 'weights': 'distance'}
# 0.754 (+/-0.123) for {'algorithm': 'kd_tree', 'n_neighbors': 7, 'p': 1, 'weights': 'uniform'}
# 0.789 (+/-0.140) for {'algorithm': 'kd_tree', 'n_neighbors': 7, 'p': 1, 'weights': 'distance'}
# 0.697 (+/-0.139) for {'algorithm': 'kd_tree', 'n_neighbors': 7, 'p': 2, 'weights': 'uniform'}
# 0.725 (+/-0.108) for {'algorithm': 'kd_tree', 'n_neighbors': 7, 'p': 2, 'weights': 'distance'}
# 0.690 (+/-0.159) for {'algorithm': 'kd_tree', 'n_neighbors': 7, 'p': 4, 'weights': 'uniform'}
# 0.697 (+/-0.100) for {'algorithm': 'kd_tree', 'n_neighbors': 7, 'p': 4, 'weights': 'distance'}
# 0.746 (+/-0.140) for {'algorithm': 'kd_tree', 'n_neighbors': 9, 'p': 1, 'weights': 'uniform'}
# 0.761 (+/-0.139) for {'algorithm': 'kd_tree', 'n_neighbors': 9, 'p': 1, 'weights': 'distance'}
# 0.711 (+/-0.170) for {'algorithm': 'kd_tree', 'n_neighbors': 9, 'p': 2, 'weights': 'uniform'}
# 0.725 (+/-0.080) for {'algorithm': 'kd_tree', 'n_neighbors': 9, 'p': 2, 'weights': 'distance'}
# 0.725 (+/-0.178) for {'algorithm': 'kd_tree', 'n_neighbors': 9, 'p': 4, 'weights': 'uniform'}
# 0.718 (+/-0.073) for {'algorithm': 'kd_tree', 'n_neighbors': 9, 'p': 4, 'weights': 'distance'}
# 0.718 (+/-0.154) for {'algorithm': 'brute', 'n_neighbors': 2, 'p': 1, 'weights': 'uniform'}
# 0.824 (+/-0.082) for {'algorithm': 'brute', 'n_neighbors': 2, 'p': 1, 'weights': 'distance'}
# 0.662 (+/-0.128) for {'algorithm': 'brute', 'n_neighbors': 2, 'p': 2, 'weights': 'uniform'}
# 0.732 (+/-0.080) for {'algorithm': 'brute', 'n_neighbors': 2, 'p': 2, 'weights': 'distance'}
# 0.662 (+/-0.133) for {'algorithm': 'brute', 'n_neighbors': 2, 'p': 4, 'weights': 'uniform'}
# 0.683 (+/-0.118) for {'algorithm': 'brute', 'n_neighbors': 2, 'p': 4, 'weights': 'distance'}
# 0.761 (+/-0.120) for {'algorithm': 'brute', 'n_neighbors': 5, 'p': 1, 'weights': 'uniform'}
# 0.803 (+/-0.109) for {'algorithm': 'brute', 'n_neighbors': 5, 'p': 1, 'weights': 'distance'}
# 0.690 (+/-0.141) for {'algorithm': 'brute', 'n_neighbors': 5, 'p': 2, 'weights': 'uniform'}
# 0.739 (+/-0.059) for {'algorithm': 'brute', 'n_neighbors': 5, 'p': 2, 'weights': 'distance'}
# 0.690 (+/-0.141) for {'algorithm': 'brute', 'n_neighbors': 5, 'p': 4, 'weights': 'uniform'}
# 0.711 (+/-0.081) for {'algorithm': 'brute', 'n_neighbors': 5, 'p': 4, 'weights': 'distance'}
# 0.754 (+/-0.123) for {'algorithm': 'brute', 'n_neighbors': 7, 'p': 1, 'weights': 'uniform'}
# 0.789 (+/-0.140) for {'algorithm': 'brute', 'n_neighbors': 7, 'p': 1, 'weights': 'distance'}
# 0.697 (+/-0.139) for {'algorithm': 'brute', 'n_neighbors': 7, 'p': 2, 'weights': 'uniform'}
# 0.725 (+/-0.108) for {'algorithm': 'brute', 'n_neighbors': 7, 'p': 2, 'weights': 'distance'}
# 0.690 (+/-0.159) for {'algorithm': 'brute', 'n_neighbors': 7, 'p': 4, 'weights': 'uniform'}
# 0.697 (+/-0.100) for {'algorithm': 'brute', 'n_neighbors': 7, 'p': 4, 'weights': 'distance'}
# 0.746 (+/-0.140) for {'algorithm': 'brute', 'n_neighbors': 9, 'p': 1, 'weights': 'uniform'}
# 0.761 (+/-0.139) for {'algorithm': 'brute', 'n_neighbors': 9, 'p': 1, 'weights': 'distance'}
# 0.711 (+/-0.170) for {'algorithm': 'brute', 'n_neighbors': 9, 'p': 2, 'weights': 'uniform'}
# 0.725 (+/-0.080) for {'algorithm': 'brute', 'n_neighbors': 9, 'p': 2, 'weights': 'distance'}
# 0.725 (+/-0.178) for {'algorithm': 'brute', 'n_neighbors': 9, 'p': 4, 'weights': 'uniform'}
# 0.718 (+/-0.073) for {'algorithm': 'brute', 'n_neighbors': 9, 'p': 4, 'weights': 'distance'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.85      0.92      0.88        12
#           1       0.79      0.73      0.76        15
#           2       0.56      0.56      0.56         9
#
# avg / total       0.75      0.75      0.75        36
#
# Detailed confusion matrix:
# [[11  0  1]
#  [ 1 11  3]
#  [ 1  3  5]]
# Accuracy Score:
#
# 0.75

# %%
# For Bagging
from sklearn.ensemble import BaggingClassifier
# This is a key step where you define the parameters and their possible values
# that you would like to check.
tuned_parameters = [{
    'n_estimators':[5,10,15],
    'max_samples':[1,2,5,10],
    'max_features':[1,3,5,7],
    'random_state':[13,78]
}
                    ]

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(BaggingClassifier(), tuned_parameters, cv=5,
                       scoring='%s' % score)
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred))
    print("Detailed confusion matrix:")
    print(confusion_matrix(y_true, y_pred))
    print("Accuracy Score: \n")
    print(accuracy_score(y_true, y_pred))

    print()
# Out:
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set:
#
# {'max_features': 7, 'max_samples': 10, 'n_estimators': 10, 'random_state': 78}
#
# Grid scores on development set:
#
# 0.359 (+/-0.105) for {'max_features': 1, 'max_samples': 1, 'n_estimators': 5, 'random_state': 13}
# 0.380 (+/-0.061) for {'max_features': 1, 'max_samples': 1, 'n_estimators': 5, 'random_state': 78}
# 0.380 (+/-0.047) for {'max_features': 1, 'max_samples': 1, 'n_estimators': 10, 'random_state': 13}
# 0.324 (+/-0.113) for {'max_features': 1, 'max_samples': 1, 'n_estimators': 10, 'random_state': 78}
# 0.338 (+/-0.075) for {'max_features': 1, 'max_samples': 1, 'n_estimators': 15, 'random_state': 13}
# 0.324 (+/-0.113) for {'max_features': 1, 'max_samples': 1, 'n_estimators': 15, 'random_state': 78}
# 0.613 (+/-0.228) for {'max_features': 1, 'max_samples': 2, 'n_estimators': 5, 'random_state': 13}
# 0.444 (+/-0.311) for {'max_features': 1, 'max_samples': 2, 'n_estimators': 5, 'random_state': 78}
# 0.627 (+/-0.255) for {'max_features': 1, 'max_samples': 2, 'n_estimators': 10, 'random_state': 13}
# 0.634 (+/-0.097) for {'max_features': 1, 'max_samples': 2, 'n_estimators': 10, 'random_state': 78}
# 0.606 (+/-0.052) for {'max_features': 1, 'max_samples': 2, 'n_estimators': 15, 'random_state': 13}
# 0.585 (+/-0.263) for {'max_features': 1, 'max_samples': 2, 'n_estimators': 15, 'random_state': 78}
# 0.648 (+/-0.063) for {'max_features': 1, 'max_samples': 5, 'n_estimators': 5, 'random_state': 13}
# 0.739 (+/-0.312) for {'max_features': 1, 'max_samples': 5, 'n_estimators': 5, 'random_state': 78}
# 0.683 (+/-0.136) for {'max_features': 1, 'max_samples': 5, 'n_estimators': 10, 'random_state': 13}
# 0.754 (+/-0.298) for {'max_features': 1, 'max_samples': 5, 'n_estimators': 10, 'random_state': 78}
# 0.831 (+/-0.107) for {'max_features': 1, 'max_samples': 5, 'n_estimators': 15, 'random_state': 13}
# 0.697 (+/-0.178) for {'max_features': 1, 'max_samples': 5, 'n_estimators': 15, 'random_state': 78}
# 0.718 (+/-0.120) for {'max_features': 1, 'max_samples': 10, 'n_estimators': 5, 'random_state': 13}
# 0.838 (+/-0.139) for {'max_features': 1, 'max_samples': 10, 'n_estimators': 5, 'random_state': 78}
# 0.796 (+/-0.115) for {'max_features': 1, 'max_samples': 10, 'n_estimators': 10, 'random_state': 13}
# 0.782 (+/-0.078) for {'max_features': 1, 'max_samples': 10, 'n_estimators': 10, 'random_state': 78}
# 0.873 (+/-0.067) for {'max_features': 1, 'max_samples': 10, 'n_estimators': 15, 'random_state': 13}
# 0.789 (+/-0.079) for {'max_features': 1, 'max_samples': 10, 'n_estimators': 15, 'random_state': 78}
# 0.359 (+/-0.105) for {'max_features': 3, 'max_samples': 1, 'n_estimators': 5, 'random_state': 13}
# 0.380 (+/-0.061) for {'max_features': 3, 'max_samples': 1, 'n_estimators': 5, 'random_state': 78}
# 0.380 (+/-0.047) for {'max_features': 3, 'max_samples': 1, 'n_estimators': 10, 'random_state': 13}
# 0.324 (+/-0.113) for {'max_features': 3, 'max_samples': 1, 'n_estimators': 10, 'random_state': 78}
# 0.338 (+/-0.075) for {'max_features': 3, 'max_samples': 1, 'n_estimators': 15, 'random_state': 13}
# 0.324 (+/-0.113) for {'max_features': 3, 'max_samples': 1, 'n_estimators': 15, 'random_state': 78}
# 0.556 (+/-0.271) for {'max_features': 3, 'max_samples': 2, 'n_estimators': 5, 'random_state': 13}
# 0.556 (+/-0.248) for {'max_features': 3, 'max_samples': 2, 'n_estimators': 5, 'random_state': 78}
# 0.563 (+/-0.143) for {'max_features': 3, 'max_samples': 2, 'n_estimators': 10, 'random_state': 13}
# 0.585 (+/-0.194) for {'max_features': 3, 'max_samples': 2, 'n_estimators': 10, 'random_state': 78}
# 0.507 (+/-0.115) for {'max_features': 3, 'max_samples': 2, 'n_estimators': 15, 'random_state': 13}
# 0.599 (+/-0.132) for {'max_features': 3, 'max_samples': 2, 'n_estimators': 15, 'random_state': 78}
# 0.768 (+/-0.225) for {'max_features': 3, 'max_samples': 5, 'n_estimators': 5, 'random_state': 13}
# 0.676 (+/-0.197) for {'max_features': 3, 'max_samples': 5, 'n_estimators': 5, 'random_state': 78}
# 0.859 (+/-0.063) for {'max_features': 3, 'max_samples': 5, 'n_estimators': 10, 'random_state': 13}
# 0.718 (+/-0.263) for {'max_features': 3, 'max_samples': 5, 'n_estimators': 10, 'random_state': 78}
# 0.887 (+/-0.079) for {'max_features': 3, 'max_samples': 5, 'n_estimators': 15, 'random_state': 13}
# 0.810 (+/-0.152) for {'max_features': 3, 'max_samples': 5, 'n_estimators': 15, 'random_state': 78}
# 0.838 (+/-0.199) for {'max_features': 3, 'max_samples': 10, 'n_estimators': 5, 'random_state': 13}
# 0.810 (+/-0.265) for {'max_features': 3, 'max_samples': 10, 'n_estimators': 5, 'random_state': 78}
# 0.880 (+/-0.133) for {'max_features': 3, 'max_samples': 10, 'n_estimators': 10, 'random_state': 13}
# 0.838 (+/-0.137) for {'max_features': 3, 'max_samples': 10, 'n_estimators': 10, 'random_state': 78}
# 0.887 (+/-0.079) for {'max_features': 3, 'max_samples': 10, 'n_estimators': 15, 'random_state': 13}
# 0.880 (+/-0.123) for {'max_features': 3, 'max_samples': 10, 'n_estimators': 15, 'random_state': 78}
# 0.359 (+/-0.105) for {'max_features': 5, 'max_samples': 1, 'n_estimators': 5, 'random_state': 13}
# 0.380 (+/-0.061) for {'max_features': 5, 'max_samples': 1, 'n_estimators': 5, 'random_state': 78}
# 0.380 (+/-0.047) for {'max_features': 5, 'max_samples': 1, 'n_estimators': 10, 'random_state': 13}
# 0.324 (+/-0.113) for {'max_features': 5, 'max_samples': 1, 'n_estimators': 10, 'random_state': 78}
# 0.338 (+/-0.075) for {'max_features': 5, 'max_samples': 1, 'n_estimators': 15, 'random_state': 13}
# 0.324 (+/-0.113) for {'max_features': 5, 'max_samples': 1, 'n_estimators': 15, 'random_state': 78}
# 0.514 (+/-0.186) for {'max_features': 5, 'max_samples': 2, 'n_estimators': 5, 'random_state': 13}
# 0.486 (+/-0.186) for {'max_features': 5, 'max_samples': 2, 'n_estimators': 5, 'random_state': 78}
# 0.556 (+/-0.105) for {'max_features': 5, 'max_samples': 2, 'n_estimators': 10, 'random_state': 13}
# 0.423 (+/-0.291) for {'max_features': 5, 'max_samples': 2, 'n_estimators': 10, 'random_state': 78}
# 0.514 (+/-0.164) for {'max_features': 5, 'max_samples': 2, 'n_estimators': 15, 'random_state': 13}
# 0.627 (+/-0.171) for {'max_features': 5, 'max_samples': 2, 'n_estimators': 15, 'random_state': 78}
# 0.648 (+/-0.234) for {'max_features': 5, 'max_samples': 5, 'n_estimators': 5, 'random_state': 13}
# 0.697 (+/-0.153) for {'max_features': 5, 'max_samples': 5, 'n_estimators': 5, 'random_state': 78}
# 0.746 (+/-0.061) for {'max_features': 5, 'max_samples': 5, 'n_estimators': 10, 'random_state': 13}
# 0.859 (+/-0.146) for {'max_features': 5, 'max_samples': 5, 'n_estimators': 10, 'random_state': 78}
# 0.824 (+/-0.120) for {'max_features': 5, 'max_samples': 5, 'n_estimators': 15, 'random_state': 13}
# 0.894 (+/-0.125) for {'max_features': 5, 'max_samples': 5, 'n_estimators': 15, 'random_state': 78}
# 0.824 (+/-0.171) for {'max_features': 5, 'max_samples': 10, 'n_estimators': 5, 'random_state': 13}
# 0.810 (+/-0.103) for {'max_features': 5, 'max_samples': 10, 'n_estimators': 5, 'random_state': 78}
# 0.873 (+/-0.052) for {'max_features': 5, 'max_samples': 10, 'n_estimators': 10, 'random_state': 13}
# 0.873 (+/-0.091) for {'max_features': 5, 'max_samples': 10, 'n_estimators': 10, 'random_state': 78}
# 0.908 (+/-0.070) for {'max_features': 5, 'max_samples': 10, 'n_estimators': 15, 'random_state': 13}
# 0.887 (+/-0.080) for {'max_features': 5, 'max_samples': 10, 'n_estimators': 15, 'random_state': 78}
# 0.359 (+/-0.105) for {'max_features': 7, 'max_samples': 1, 'n_estimators': 5, 'random_state': 13}
# 0.380 (+/-0.061) for {'max_features': 7, 'max_samples': 1, 'n_estimators': 5, 'random_state': 78}
# 0.380 (+/-0.047) for {'max_features': 7, 'max_samples': 1, 'n_estimators': 10, 'random_state': 13}
# 0.324 (+/-0.113) for {'max_features': 7, 'max_samples': 1, 'n_estimators': 10, 'random_state': 78}
# 0.338 (+/-0.075) for {'max_features': 7, 'max_samples': 1, 'n_estimators': 15, 'random_state': 13}
# 0.324 (+/-0.113) for {'max_features': 7, 'max_samples': 1, 'n_estimators': 15, 'random_state': 78}
# 0.472 (+/-0.193) for {'max_features': 7, 'max_samples': 2, 'n_estimators': 5, 'random_state': 13}
# 0.507 (+/-0.240) for {'max_features': 7, 'max_samples': 2, 'n_estimators': 5, 'random_state': 78}
# 0.479 (+/-0.128) for {'max_features': 7, 'max_samples': 2, 'n_estimators': 10, 'random_state': 13}
# 0.585 (+/-0.179) for {'max_features': 7, 'max_samples': 2, 'n_estimators': 10, 'random_state': 78}
# 0.528 (+/-0.207) for {'max_features': 7, 'max_samples': 2, 'n_estimators': 15, 'random_state': 13}
# 0.613 (+/-0.186) for {'max_features': 7, 'max_samples': 2, 'n_estimators': 15, 'random_state': 78}
# 0.669 (+/-0.140) for {'max_features': 7, 'max_samples': 5, 'n_estimators': 5, 'random_state': 13}
# 0.810 (+/-0.137) for {'max_features': 7, 'max_samples': 5, 'n_estimators': 5, 'random_state': 78}
# 0.817 (+/-0.137) for {'max_features': 7, 'max_samples': 5, 'n_estimators': 10, 'random_state': 13}
# 0.824 (+/-0.141) for {'max_features': 7, 'max_samples': 5, 'n_estimators': 10, 'random_state': 78}
# 0.824 (+/-0.137) for {'max_features': 7, 'max_samples': 5, 'n_estimators': 15, 'random_state': 13}
# 0.789 (+/-0.126) for {'max_features': 7, 'max_samples': 5, 'n_estimators': 15, 'random_state': 78}
# 0.894 (+/-0.076) for {'max_features': 7, 'max_samples': 10, 'n_estimators': 5, 'random_state': 13}
# 0.908 (+/-0.082) for {'max_features': 7, 'max_samples': 10, 'n_estimators': 5, 'random_state': 78}
# 0.908 (+/-0.090) for {'max_features': 7, 'max_samples': 10, 'n_estimators': 10, 'random_state': 13}
# 0.937 (+/-0.124) for {'max_features': 7, 'max_samples': 10, 'n_estimators': 10, 'random_state': 78}
# 0.937 (+/-0.100) for {'max_features': 7, 'max_samples': 10, 'n_estimators': 15, 'random_state': 13}
# 0.901 (+/-0.071) for {'max_features': 7, 'max_samples': 10, 'n_estimators': 15, 'random_state': 78}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.92      0.92      0.92        12
#           1       0.88      0.93      0.90        15
#           2       1.00      0.89      0.94         9
#
# avg / total       0.92      0.92      0.92        36
#
# Detailed confusion matrix:
# [[11  1  0]
#  [ 1 14  0]
#  [ 0  1  8]]
# Accuracy Score:
#
# 0.9166666666666666

# %%
# For Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier
# This is a key step where you define the parameters and their possible values
# that you would like to check.
tuned_parameters = [{
    'n_estimators':[10,100,150,300],
    'criterion':['gini','entropy'],
    'max_depth':[5,10,20],
    'max_features':['sqrt','log2']
}]

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(RandomForestClassifier(), tuned_parameters, cv=5,
                       scoring='%s' % score)
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred))
    print("Detailed confusion matrix:")
    print(confusion_matrix(y_true, y_pred))
    print("Accuracy Score: \n")
    print(accuracy_score(y_true, y_pred))

    print()
# Out:
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set:
#
# {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 100}
#
# Grid scores on development set:
#
# 0.951 (+/-0.083) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 10}
# 0.979 (+/-0.035) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 100}
# 0.979 (+/-0.056) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 150}
# 0.979 (+/-0.035) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 300}
# 0.951 (+/-0.071) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 10}
# 0.986 (+/-0.035) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 100}
# 0.979 (+/-0.035) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 150}
# 0.972 (+/-0.053) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 300}
# 0.972 (+/-0.053) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 10}
# 0.979 (+/-0.056) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 100}
# 0.972 (+/-0.053) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 150}
# 0.986 (+/-0.035) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 300}
# 0.979 (+/-0.058) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 10}
# 0.972 (+/-0.029) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 100}
# 0.979 (+/-0.035) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 150}
# 0.979 (+/-0.035) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 300}
# 0.951 (+/-0.034) for {'criterion': 'gini', 'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 10}
# 0.972 (+/-0.053) for {'criterion': 'gini', 'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 100}
# 0.972 (+/-0.028) for {'criterion': 'gini', 'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 150}
# 0.979 (+/-0.056) for {'criterion': 'gini', 'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 300}
# 0.951 (+/-0.057) for {'criterion': 'gini', 'max_depth': 20, 'max_features': 'log2', 'n_estimators': 10}
# 0.979 (+/-0.056) for {'criterion': 'gini', 'max_depth': 20, 'max_features': 'log2', 'n_estimators': 100}
# 0.979 (+/-0.035) for {'criterion': 'gini', 'max_depth': 20, 'max_features': 'log2', 'n_estimators': 150}
# 0.979 (+/-0.035) for {'criterion': 'gini', 'max_depth': 20, 'max_features': 'log2', 'n_estimators': 300}
# 0.965 (+/-0.044) for {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 10}
# 0.972 (+/-0.081) for {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 100}
# 0.986 (+/-0.035) for {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 150}
# 0.979 (+/-0.056) for {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 300}
# 0.944 (+/-0.055) for {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 10}
# 0.979 (+/-0.056) for {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 100}
# 0.979 (+/-0.056) for {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 150}
# 0.979 (+/-0.056) for {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 300}
# 0.965 (+/-0.045) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 10}
# 0.979 (+/-0.056) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 100}
# 0.979 (+/-0.056) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 150}
# 0.986 (+/-0.035) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 300}
# 0.972 (+/-0.053) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 10}
# 0.979 (+/-0.056) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 100}
# 0.979 (+/-0.056) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 150}
# 0.986 (+/-0.035) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 300}
# 0.951 (+/-0.037) for {'criterion': 'entropy', 'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 10}
# 0.979 (+/-0.056) for {'criterion': 'entropy', 'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 100}
# 0.979 (+/-0.056) for {'criterion': 'entropy', 'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 150}
# 0.986 (+/-0.035) for {'criterion': 'entropy', 'max_depth': 20, 'max_features': 'sqrt', 'n_estimators': 300}
# 0.958 (+/-0.083) for {'criterion': 'entropy', 'max_depth': 20, 'max_features': 'log2', 'n_estimators': 10}
# 0.965 (+/-0.076) for {'criterion': 'entropy', 'max_depth': 20, 'max_features': 'log2', 'n_estimators': 100}
# 0.986 (+/-0.035) for {'criterion': 'entropy', 'max_depth': 20, 'max_features': 'log2', 'n_estimators': 150}
# 0.979 (+/-0.056) for {'criterion': 'entropy', 'max_depth': 20, 'max_features': 'log2', 'n_estimators': 300}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00        12
#           1       1.00      1.00      1.00        15
#           2       1.00      1.00      1.00         9
#
# avg / total       1.00      1.00      1.00        36
#
# Detailed confusion matrix:
# [[12  0  0]
#  [ 0 15  0]
#  [ 0  0  9]]
# Accuracy Score:
#
# 1.0

# %%
# For AdaBoost Classifier
from sklearn.ensemble import AdaBoostClassifier
# This is a key step where you define the parameters and their possible values
# that you would like to check.
tuned_parameters = [{
    'n_estimators':[50,100],
    'learning_rate':[1,2],
    'algorithm':['SAMME'],
    'random_state':[15,78]
}]

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(AdaBoostClassifier(), tuned_parameters, cv=5,
                       scoring='%s' % score)
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred))
    print("Detailed confusion matrix:")
    print(confusion_matrix(y_true, y_pred))
    print("Accuracy Score: \n")
    print(accuracy_score(y_true, y_pred))

    print()
# Out:
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set:
#
# {'algorithm': 'SAMME', 'learning_rate': 1, 'n_estimators': 50, 'random_state': 15}
#
# Grid scores on development set:
#
# 0.979 (+/-0.056) for {'algorithm': 'SAMME', 'learning_rate': 1, 'n_estimators': 50, 'random_state': 15}
# 0.979 (+/-0.056) for {'algorithm': 'SAMME', 'learning_rate': 1, 'n_estimators': 50, 'random_state': 78}
# 0.979 (+/-0.034) for {'algorithm': 'SAMME', 'learning_rate': 1, 'n_estimators': 100, 'random_state': 15}
# 0.979 (+/-0.034) for {'algorithm': 'SAMME', 'learning_rate': 1, 'n_estimators': 100, 'random_state': 78}
# 0.697 (+/-0.276) for {'algorithm': 'SAMME', 'learning_rate': 2, 'n_estimators': 50, 'random_state': 15}
# 0.704 (+/-0.287) for {'algorithm': 'SAMME', 'learning_rate': 2, 'n_estimators': 50, 'random_state': 78}
# 0.592 (+/-0.215) for {'algorithm': 'SAMME', 'learning_rate': 2, 'n_estimators': 100, 'random_state': 15}
# 0.641 (+/-0.347) for {'algorithm': 'SAMME', 'learning_rate': 2, 'n_estimators': 100, 'random_state': 78}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00        12
#           1       0.94      1.00      0.97        15
#           2       1.00      0.89      0.94         9
#
# avg / total       0.97      0.97      0.97        36
#
# Detailed confusion matrix:
# [[12  0  0]
#  [ 0 15  0]
#  [ 0  1  8]]
# Accuracy Score:
#
# 0.9722222222222222

# %%
# For Gradient Boosting Classifier
from sklearn.ensemble import GradientBoostingClassifier
# This is a key step where you define the parameters and their possible values
# that you would like to check.
tuned_parameters = [{
    'n_estimators':[50,100],
    'learning_rate':[0.1,0.2],
    'max_depth':[3,6,10],
    'max_features':[10],
    'min_samples_leaf':[1,2]
}]

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(GradientBoostingClassifier(), tuned_parameters, cv=5,
                       scoring='%s' % score)
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred))
    print("Detailed confusion matrix:")
    print(confusion_matrix(y_true, y_pred))
    print("Accuracy Score: \n")
    print(accuracy_score(y_true, y_pred))

    print()
# Out:
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set:
#
# {'learning_rate': 0.2, 'max_depth': 3, 'max_features': 10, 'min_samples_leaf': 2, 'n_estimators': 100}
#
# Grid scores on development set:
#
# 0.965 (+/-0.061) for {'learning_rate': 0.1, 'max_depth': 3, 'max_features': 10, 'min_samples_leaf': 1, 'n_estimators': 50}
# 0.951 (+/-0.069) for {'learning_rate': 0.1, 'max_depth': 3, 'max_features': 10, 'min_samples_leaf': 1, 'n_estimators': 100}
# 0.958 (+/-0.068) for {'learning_rate': 0.1, 'max_depth': 3, 'max_features': 10, 'min_samples_leaf': 2, 'n_estimators': 50}
# 0.972 (+/-0.053) for {'learning_rate': 0.1, 'max_depth': 3, 'max_features': 10, 'min_samples_leaf': 2, 'n_estimators': 100}
# 0.937 (+/-0.077) for {'learning_rate': 0.1, 'max_depth': 6, 'max_features': 10, 'min_samples_leaf': 1, 'n_estimators': 50}
# 0.972 (+/-0.052) for {'learning_rate': 0.1, 'max_depth': 6, 'max_features': 10, 'min_samples_leaf': 1, 'n_estimators': 100}
# 0.965 (+/-0.076) for {'learning_rate': 0.1, 'max_depth': 6, 'max_features': 10, 'min_samples_leaf': 2, 'n_estimators': 50}
# 0.958 (+/-0.068) for {'learning_rate': 0.1, 'max_depth': 6, 'max_features': 10, 'min_samples_leaf': 2, 'n_estimators': 100}
# 0.944 (+/-0.032) for {'learning_rate': 0.1, 'max_depth': 10, 'max_features': 10, 'min_samples_leaf': 1, 'n_estimators': 50}
# 0.951 (+/-0.069) for {'learning_rate': 0.1, 'max_depth': 10, 'max_features': 10, 'min_samples_leaf': 1, 'n_estimators': 100}
# 0.972 (+/-0.028) for {'learning_rate': 0.1, 'max_depth': 10, 'max_features': 10, 'min_samples_leaf': 2, 'n_estimators': 50}
# 0.965 (+/-0.076) for {'learning_rate': 0.1, 'max_depth': 10, 'max_features': 10, 'min_samples_leaf': 2, 'n_estimators': 100}
# 0.958 (+/-0.080) for {'learning_rate': 0.2, 'max_depth': 3, 'max_features': 10, 'min_samples_leaf': 1, 'n_estimators': 50}
# 0.951 (+/-0.031) for {'learning_rate': 0.2, 'max_depth': 3, 'max_features': 10, 'min_samples_leaf': 1, 'n_estimators': 100}
# 0.958 (+/-0.082) for {'learning_rate': 0.2, 'max_depth': 3, 'max_features': 10, 'min_samples_leaf': 2, 'n_estimators': 50}
# 0.979 (+/-0.056) for {'learning_rate': 0.2, 'max_depth': 3, 'max_features': 10, 'min_samples_leaf': 2, 'n_estimators': 100}
# 0.937 (+/-0.100) for {'learning_rate': 0.2, 'max_depth': 6, 'max_features': 10, 'min_samples_leaf': 1, 'n_estimators': 50}
# 0.944 (+/-0.032) for {'learning_rate': 0.2, 'max_depth': 6, 'max_features': 10, 'min_samples_leaf': 1, 'n_estimators': 100}
# 0.972 (+/-0.053) for {'learning_rate': 0.2, 'max_depth': 6, 'max_features': 10, 'min_samples_leaf': 2, 'n_estimators': 50}
# 0.958 (+/-0.102) for {'learning_rate': 0.2, 'max_depth': 6, 'max_features': 10, 'min_samples_leaf': 2, 'n_estimators': 100}
# 0.958 (+/-0.050) for {'learning_rate': 0.2, 'max_depth': 10, 'max_features': 10, 'min_samples_leaf': 1, 'n_estimators': 50}
# 0.951 (+/-0.031) for {'learning_rate': 0.2, 'max_depth': 10, 'max_features': 10, 'min_samples_leaf': 1, 'n_estimators': 100}
# 0.958 (+/-0.102) for {'learning_rate': 0.2, 'max_depth': 10, 'max_features': 10, 'min_samples_leaf': 2, 'n_estimators': 50}
# 0.972 (+/-0.053) for {'learning_rate': 0.2, 'max_depth': 10, 'max_features': 10, 'min_samples_leaf': 2, 'n_estimators': 100}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00        12
#           1       1.00      1.00      1.00        15
#           2       1.00      1.00      1.00         9
#
# avg / total       1.00      1.00      1.00        36
#
# Detailed confusion matrix:
# [[12  0  0]
#  [ 0 15  0]
#  [ 0  0  9]]
# Accuracy Score:
#
# 1.0

# %%
# For Neural Network
from sklearn.neural_network import MLPClassifier
# This is a key step where you define the parameters and their possible values
# that you would like to check.
tuned_parameters = [{
    'hidden_layer_sizes':[5,15,25,50,100],
    'activation':['relu','logistic','tanh'],
    'alpha':[0.0001],
    'learning_rate':['constant'],
    'solver':['lbfgs']
#     'max_iter':[5000]
}]

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(MLPClassifier(), tuned_parameters, cv=5,
                       scoring='%s' % score)
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred))
    print("Detailed confusion matrix:")
    print(confusion_matrix(y_true, y_pred))
    print("Accuracy Score: \n")
    print(accuracy_score(y_true, y_pred))

    print()
# Out:
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set:
#
# {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': 50, 'learning_rate': 'constant', 'solver': 'lbfgs'}
#
# Grid scores on development set:
#
# 0.606 (+/-0.392) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': 5, 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.444 (+/-0.262) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': 15, 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.655 (+/-0.479) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': 25, 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.556 (+/-0.425) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': 50, 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.451 (+/-0.308) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': 100, 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.394 (+/-0.019) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': 5, 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.493 (+/-0.244) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': 15, 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.535 (+/-0.382) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': 25, 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.789 (+/-0.201) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': 50, 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.683 (+/-0.283) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': 100, 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.394 (+/-0.019) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': 5, 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.521 (+/-0.302) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': 15, 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.514 (+/-0.298) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': 25, 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.725 (+/-0.174) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': 50, 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.768 (+/-0.266) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': 100, 'learning_rate': 'constant', 'solver': 'lbfgs'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00        12
#           1       0.83      1.00      0.91        15
#           2       1.00      0.67      0.80         9
#
# avg / total       0.93      0.92      0.91        36
#
# Detailed confusion matrix:
# [[12  0  0]
#  [ 0 15  0]
#  [ 0  3  6]]
# Accuracy Score:
#
# 0.9166666666666666

# %%
# For XGBoost Classifier
from xgboost import XGBClassifier
# This is a key step where you define the parameters and their possible values
# that you would like to check.
tuned_parameters = [{
   'objective':['reg:linear'],
    'colsample_bytree':[0.3], 
    'learning_rate' : [0.1,0.2],
    'max_depth':[5],
    'n_estimators':[10]
}]

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(XGBClassifier(), tuned_parameters, cv=5,
                       scoring='%s' % score)
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred))
    print("Detailed confusion matrix:")
    print(confusion_matrix(y_true, y_pred))
    print("Accuracy Score: \n")
    print(accuracy_score(y_true, y_pred))

    print()
# Out:
# # Tuning hyper-parameters for accuracy
#
# Best parameters set found on development set:
#
# {'colsample_bytree': 0.3, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 10, 'objective': 'reg:linear'}
#
# Grid scores on development set:
#
# 0.972 (+/-0.029) for {'colsample_bytree': 0.3, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 10, 'objective': 'reg:linear'}
# 0.951 (+/-0.057) for {'colsample_bytree': 0.3, 'learning_rate': 0.2, 'max_depth': 5, 'n_estimators': 10, 'objective': 'reg:linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00        12
#           1       1.00      1.00      1.00        15
#           2       1.00      1.00      1.00         9
#
# avg / total       1.00      1.00      1.00        36
#
# Detailed confusion matrix:
# [[12  0  0]
#  [ 0 15  0]
#  [ 0  0  9]]
# Accuracy Score:
#
# 1.0
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
